# %%
import pandas as pd

# %%
prescriptions_df=pd.read_csv("PRESCRIPTIONS.csv")
admissions_df=pd.read_csv("ADMISSIONS.csv")

# %%
prescriptions_df["route"]
# Out:
# 0             IM
# 1             PO
# 2             PR
# 3             PO
# 4             PO
#           ...
# 10393         IV
# 10394         PR
# 10395         IV
# 10396         IV
# 10397    IV DRIP
# Name: route, Length: 10398, dtype: object

# %%
opioids = [
    'Morphine', 'Oxycodone', 'Hydrocodone', 'Fentanyl', 'Codeine', 
    'Hydromorphone', 'Methadone', 'Buprenorphine', 'Oxymorphone', 'Meperidine',
    'Tapentadol', 'Tramadol', 'Alfentanil', 'Remifentanil', 'Sufentanil', 
    'Levorphanol', 'Nalbuphine', 'Butorphanol', 'Pentazocine', 'Dihydrocodeine',
    'Loperamide', 'Diphenoxylate', 'Desomorphine', 'Etorphine', 'Naloxone', 
    'Naltrexone', 'Poppy Seeds', 'Pethidine', 'Nalbuphine', 'Bupropion', 
    'Bupivacaine', 'Dextropropoxyphene', 'Methylnaltrexone', 'Oxymetazoline', 
    'Dextromethorphan', 'Clonidine', 'Naloxegol', 'Naltrexone', 'Phenazocine', 
    'Proglumide', 'Furanylfentanyl', 'Acetylfentanyl', 'Carfentanil', 
    'Beta-hydroxyfentanyl', '3-Methylfentanyl', '4-Anilino-N-phenethylpiperidine', 
    'AP-237', 'Norfentanyl', 'Hydroxycodone', 'Oxycodone', 'Ethylmorphine', 
    'Piritramide', 'Alphaprodine', 'Piperidine', 'Anileridine', 'Etorphine', 
    'Diphenoxylate', 'Lofexidine', 'Dextropropoxyphene', 'Methadone Hydrochloride', 
    'Methadone HCl', 'Fentanyl Citrate', 'Hydromorphone Hydrochloride', 
    'Levorphanol Tartrate', 'Buprenorphine Hydrochloride', 'Nalbuphine Hydrochloride', 
    'Butorphanol Tartrate', 'Oxymorphone Hydrochloride', 'Propoxyphene', 
    'Cox-2 inhibitors', 'Suboxone', 'Subutex', 'Embeda', 'Kadian', 'Roxycodone', 
    'Oxecta', 'Zohydro', 'Hysingla ER', 'Oxycontin', 'Fentora', 'Actiq', 
    'Duragesic', 'Sublimaze', 'Sublocade', 'Buprenex', 'Norco', 'Vicodin', 
    'Lorcet', 'Percocet', 'Tylox', 'Dilaudid', 'Exalgo', 'Opana', 'Avinza', 
    'MS Contin', 'OxyIR', 'Belbuca', 'Cassipa', 'Subutex', 'Lofexidine'
]

# %%
prescriptions_df
# Out:
#         row_id  subject_id  hadm_id  icustay_id            startdate  \
# 0        32600       42458   159647         NaN  2146-07-21 00:00:00
# 1        32601       42458   159647         NaN  2146-07-21 00:00:00
# 2        32602       42458   159647         NaN  2146-07-21 00:00:00
# 3        32603       42458   159647         NaN  2146-07-21 00:00:00
# 4        32604       42458   159647         NaN  2146-07-21 00:00:00
# ...        ...         ...      ...         ...                  ...
# 10393  3609913       42430   100969    210474.0  2142-11-29 00:00:00
# 10394  3609914       42430   100969    210474.0  2142-11-30 00:00:00
# 10395  3609915       42430   100969         NaN  2142-11-26 00:00:00
# 10396  3609916       42430   100969         NaN  2142-11-26 00:00:00
# 10397  3609917       42430   100969         NaN  2142-11-26 00:00:00
#
#                    enddate drug_type                         drug  \
# 0      2146-07-22 00:00:00      MAIN  Pneumococcal Vac Polyvalent
# ...

# %%
set(prescriptions_df["drug_name_generic"])
# Out:
# {'*NF* Bimatoprost  0.03%  Ophth',
#  '*NF* Cabergoline',
#  '*NF* Candesartan Cilexetil',
#  '*NF* Cilostazol',
#  '*NF* Cromolyn Sodium 4% Opth',
#  '*NF* Demeclocycline',
#  '*NF* Fosinopril Sodium',
#  '*NF* Ketorolac 0.5% Ophth Soln',
#  '*NF* Levalbuterol Neb',
#  '*NF* Levalbuterol Soln',
#  '*NF* Memantine',
#  '*NF* Moxifloxacin 0.5% Ophth',
#  '*NF* Rivastigmine Tartrate',
#  'Acebutolol HCl',
#  'AcetaZOLamide',
#  'Acetaminophen',
#  'Acetaminophen (Liquid)',
#  'Acetaminophen (Rectal)',
#  'Acetaminophen IV',
#  'Acetaminophen w/Codeine',
#  'Acetylcysteine 20%',
#  'Acyclovir',
#  'Adenosine',
#  'Albumin 25% (12.5 g)',
#  'Albumin 25% (12.5g / 50mL)',
#  'Albumin 25% (12.5gm)',
#  'Albumin 5% (12.5 g)',
#  'Albumin 5% (12.5g / 250mL)',
#  'Albumin 5% (25 g)',
#  'Albumin 5% (25g / 500mL)',
#  'Albuterol 0.083% Neb Soln',
#  'Albuterol Inhaler',
#  'Albuterol Inhaler (ProAir)',
#  'Albuterol Neb Soln',
#  'Albuterol Sulfate-Ipratropium',
#  'Alendronate Sodium',
# ...

# %%
prescriptions_df
# Out:
#         row_id  subject_id  hadm_id  icustay_id            startdate  \
# 0        32600       42458   159647         NaN  2146-07-21 00:00:00
# 1        32601       42458   159647         NaN  2146-07-21 00:00:00
# 2        32602       42458   159647         NaN  2146-07-21 00:00:00
# 3        32603       42458   159647         NaN  2146-07-21 00:00:00
# 4        32604       42458   159647         NaN  2146-07-21 00:00:00
# ...        ...         ...      ...         ...                  ...
# 10393  3609913       42430   100969    210474.0  2142-11-29 00:00:00
# 10394  3609914       42430   100969    210474.0  2142-11-30 00:00:00
# 10395  3609915       42430   100969         NaN  2142-11-26 00:00:00
# 10396  3609916       42430   100969         NaN  2142-11-26 00:00:00
# 10397  3609917       42430   100969         NaN  2142-11-26 00:00:00
#
#                    enddate drug_type                         drug  \
# 0      2146-07-22 00:00:00      MAIN  Pneumococcal Vac Polyvalent
# ...

# %%
prescriptions_df["startdate"]=prescriptions_df["startdate"].apply(lambda x:x[0]+"0"+"0"+x[3:] )

# %%
prescriptions_df["startdate"]=prescriptions_df["startdate"].apply(lambda x:x[0]+"0"+"0"+x[3:] )
prescriptions_df["enddate"]=prescriptions_df["enddate"].apply(lambda x:str(x))
prescriptions_df["enddate"]=prescriptions_df["enddate"].apply(lambda x:x[0]+"0"+"0"+x[3:] )

# %%
prescriptions_df
# Out:
#         row_id  subject_id  hadm_id  icustay_id            startdate  \
# 0        32600       42458   159647         NaN  2006-07-21 00:00:00
# 1        32601       42458   159647         NaN  2006-07-21 00:00:00
# 2        32602       42458   159647         NaN  2006-07-21 00:00:00
# 3        32603       42458   159647         NaN  2006-07-21 00:00:00
# 4        32604       42458   159647         NaN  2006-07-21 00:00:00
# ...        ...         ...      ...         ...                  ...
# 10393  3609913       42430   100969    210474.0  2002-11-29 00:00:00
# 10394  3609914       42430   100969    210474.0  2002-11-30 00:00:00
# 10395  3609915       42430   100969         NaN  2002-11-26 00:00:00
# 10396  3609916       42430   100969         NaN  2002-11-26 00:00:00
# 10397  3609917       42430   100969         NaN  2002-11-26 00:00:00
#
#                    enddate drug_type                         drug  \
# 0      2006-07-22 00:00:00      MAIN  Pneumococcal Vac Polyvalent
# ...

# %%
prescriptions_df
# Out:
#         row_id  subject_id  hadm_id  icustay_id            startdate  \
# 0        32600       42458   159647         NaN  2006-07-21 00:00:00
# 1        32601       42458   159647         NaN  2006-07-21 00:00:00
# 2        32602       42458   159647         NaN  2006-07-21 00:00:00
# 3        32603       42458   159647         NaN  2006-07-21 00:00:00
# 4        32604       42458   159647         NaN  2006-07-21 00:00:00
# ...        ...         ...      ...         ...                  ...
# 10393  3609913       42430   100969    210474.0  2002-11-29 00:00:00
# 10394  3609914       42430   100969    210474.0  2002-11-30 00:00:00
# 10395  3609915       42430   100969         NaN  2002-11-26 00:00:00
# 10396  3609916       42430   100969         NaN  2002-11-26 00:00:00
# 10397  3609917       42430   100969         NaN  2002-11-26 00:00:00
#
#                    enddate drug_type                         drug  \
# 0      2006-07-22 00:00:00      MAIN  Pneumococcal Vac Polyvalent
# ...

# %%
admissions_df
# Out:
#      row_id  subject_id  hadm_id            admittime            dischtime  \
# 0     12258       10006   142345  2164-10-23 21:09:00  2164-11-01 17:15:00
# 1     12263       10011   105331  2126-08-14 22:32:00  2126-08-28 18:59:00
# 2     12265       10013   165520  2125-10-04 23:36:00  2125-10-07 15:13:00
# 3     12269       10017   199207  2149-05-26 17:19:00  2149-06-03 18:42:00
# 4     12270       10019   177759  2163-05-14 20:43:00  2163-05-15 12:00:00
# ..      ...         ...      ...                  ...                  ...
# 124   41055       44083   198330  2112-05-28 15:45:00  2112-06-07 16:50:00
# 125   41070       44154   174245  2178-05-14 20:29:00  2178-05-15 09:45:00
# 126   41087       44212   163189  2123-11-24 14:14:00  2123-12-30 14:31:00
# 127   41090       44222   192189  2180-07-19 06:55:00  2180-07-20 13:00:00
# 128   41092       44228   103379  2170-12-15 03:14:00  2170-12-24 18:00:00
#
# ...

# %%
admissions_df["admittime"]=admissions_df["admittime"].apply(lambda x:x[0]+"0"+"0"+x[3:])
admissions_df["dischtime"]=admissions_df["dischtime"].apply(lambda x:x[0]+"0"+"0"+x[3:])

# %%
admissions_df
# Out:
#      row_id  subject_id  hadm_id            admittime            dischtime  \
# 0     12258       10006   142345  2004-10-23 21:09:00  2004-11-01 17:15:00
# 1     12263       10011   105331  2006-08-14 22:32:00  2006-08-28 18:59:00
# 2     12265       10013   165520  2005-10-04 23:36:00  2005-10-07 15:13:00
# 3     12269       10017   199207  2009-05-26 17:19:00  2009-06-03 18:42:00
# 4     12270       10019   177759  2003-05-14 20:43:00  2003-05-15 12:00:00
# ..      ...         ...      ...                  ...                  ...
# 124   41055       44083   198330  2002-05-28 15:45:00  2002-06-07 16:50:00
# 125   41070       44154   174245  2008-05-14 20:29:00  2008-05-15 09:45:00
# 126   41087       44212   163189  2003-11-24 14:14:00  2003-12-30 14:31:00
# 127   41090       44222   192189  2000-07-19 06:55:00  2000-07-20 13:00:00
# 128   41092       44228   103379  2000-12-15 03:14:00  2000-12-24 18:00:00
#
# ...

# %%
merged_df = pd.merge(admissions_df,prescriptions_df, on=['subject_id', 'hadm_id'], how='left', indicator=True
                                                         )

# %%
merged_df
# Out:
#        row_id_x  subject_id  hadm_id            admittime  \
# 0         12258       10006   142345  2004-10-23 21:09:00
# 1         12258       10006   142345  2004-10-23 21:09:00
# 2         12258       10006   142345  2004-10-23 21:09:00
# 3         12258       10006   142345  2004-10-23 21:09:00
# 4         12258       10006   142345  2004-10-23 21:09:00
# ...         ...         ...      ...                  ...
# 10400     41092       44228   103379  2000-12-15 03:14:00
# 10401     41092       44228   103379  2000-12-15 03:14:00
# 10402     41092       44228   103379  2000-12-15 03:14:00
# 10403     41092       44228   103379  2000-12-15 03:14:00
# 10404     41092       44228   103379  2000-12-15 03:14:00
#
#                  dischtime deathtime admission_type    admission_location  \
# 0      2004-11-01 17:15:00       NaN      EMERGENCY  EMERGENCY ROOM ADMIT
# 1      2004-11-01 17:15:00       NaN      EMERGENCY  EMERGENCY ROOM ADMIT
# ...

# %%
c=merged_df["subject_id"].value_counts()

# %%
c
# Out:
# 41976    1158
# 40310     893
# 10126     437
# 10124     315
# 10061     314
#          ...
# 10069       1
# 10114       1
# 10130       1
# 10011       1
# 10046       1
# Name: subject_id, Length: 100, dtype: int64

# %%
len(c[c>1])
# Out:
# 94

# %%
c=merged_df.columns

# %%
merged_df["opioid_abuse"]=merged_df["_merge"].apply(lambda x:"yes" if x=="both" else "no" )

# %%
merged_df.head()
# Out:
#    row_id_x  subject_id  hadm_id            admittime            dischtime  \
# 0     12258       10006   142345  2004-10-23 21:09:00  2004-11-01 17:15:00
# 1     12258       10006   142345  2004-10-23 21:09:00  2004-11-01 17:15:00
# 2     12258       10006   142345  2004-10-23 21:09:00  2004-11-01 17:15:00
# 3     12258       10006   142345  2004-10-23 21:09:00  2004-11-01 17:15:00
# 4     12258       10006   142345  2004-10-23 21:09:00  2004-11-01 17:15:00
#
#   deathtime admission_type    admission_location discharge_location insurance  \
# 0       NaN      EMERGENCY  EMERGENCY ROOM ADMIT   HOME HEALTH CARE  Medicare
# 1       NaN      EMERGENCY  EMERGENCY ROOM ADMIT   HOME HEALTH CARE  Medicare
# 2       NaN      EMERGENCY  EMERGENCY ROOM ADMIT   HOME HEALTH CARE  Medicare
# 3       NaN      EMERGENCY  EMERGENCY ROOM ADMIT   HOME HEALTH CARE  Medicare
# 4       NaN      EMERGENCY  EMERGENCY ROOM ADMIT   HOME HEALTH CARE  Medicare
#
# ...

# %%
merged_df['startdate'] = pd.to_datetime(merged_df['startdate'], errors='coerce')
merged_df['enddate'] = pd.to_datetime(merged_df['enddate'], errors='coerce')
merged_df['admittime'] = pd.to_datetime(merged_df['admittime'], errors='coerce')
merged_df['dischtime'] = pd.to_datetime(merged_df['dischtime'], errors='coerce')

# %%
merged_df['startdate'].fillna(pd.Timestamp('2002-01-01'), inplace=True)
merged_df['enddate'].fillna(pd.Timestamp('2002-01-01'), inplace=True)
merged_df['admittime'].fillna(pd.Timestamp('2002-01-01'), inplace=True)
merged_df['dischtime'].fillna(pd.Timestamp('2002-01-01'), inplace=True)

# %%
merged_df
# Out:
#        row_id_x  subject_id  hadm_id           admittime           dischtime  \
# 0         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 1         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 2         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 3         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 4         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# ...         ...         ...      ...                 ...                 ...
# 10400     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10401     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10402     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10403     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10404     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
#
# ...

# %%
group_df=merged_df.groupby("subject_id")

# %%
for i in group_df:
    print(i)bb
# Out:
# (10006,     row_id_x  subject_id  hadm_id           admittime           dischtime  \
# 0      12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 1      12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 2      12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 3      12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 4      12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 5      12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 6      12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 7      12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 8      12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 9      12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 10     12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 11     12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# ...

# %%
group=group_df.get_group(10006)

# %%
group.columns
# Out:
# Index(['row_id_x', 'subject_id', 'hadm_id', 'admittime', 'dischtime',
#        'deathtime', 'admission_type', 'admission_location',
#        'discharge_location', 'insurance', 'language', 'religion',
#        'marital_status', 'ethnicity', 'edregtime', 'edouttime', 'diagnosis',
#        'hospital_expire_flag', 'has_chartevents_data', 'row_id_y',
#        'icustay_id', 'startdate', 'enddate', 'drug_type', 'drug',
#        'drug_name_poe', 'drug_name_generic', 'formulary_drug_cd', 'gsn', 'ndc',
#        'prod_strength', 'dose_val_rx', 'dose_unit_rx', 'form_val_disp',
#        'form_unit_disp', 'route', '_merge', 'opioid_abuse'],
#       dtype='object')

# %%
group=group.sort_values(by="enddate")

# %%
len(group["drug"])
# Out:
# 54

# %%
len(set(group[:][:30]["drug"]))
# Out:
# 19

# %%
len(set(group["drug"]))
# Out:
# 34

# %%
group["form_val_disp"]
# Out:
# 39     0.5
# 1        1
# 48      50
# 38    1000
# 36       1
# 37       1
# 47     250
# 46     100
# 45      50
# 49     100
# 7        1
# 10       4
# 11       1
# 13       1
# 40       1
# 16     0.5
# 14       1
# 12       2
# 20     0.5
# 42       1
# 51     200
# 17     0.5
# 3        1
# 18       1
# 19       1
# 22       1
# 31       2
# 43       6
# 52     250
# 27       1
# 0      0.6
# 44     1.5
# 50     200
# 41       1
# 35       1
# 26       1
# 33       1
# 2        3
# 4        0
# 5        1
# 6      1-2
# 8        1
# 9        1
# 15       1
# 21     1-2
# 23       1
# 24       1
# 25       1
# 28       1
# 29       1
# 30     0.5
# 32       2
# 34       1
# 53     250
# Name: form_val_disp, dtype: object

# %%
g=group[:30]

# %%
g.values
# Out:
# array([[12258, 10006, 142345, ..., 'IV', 'both', 'yes'],
#        [12258, 10006, 142345, ..., 'PO', 'both', 'yes'],
#        [12258, 10006, 142345, ..., 'IV', 'both', 'yes'],
#        ...,
#        [12258, 10006, 142345, ..., 'IV', 'both', 'yes'],
#        [12258, 10006, 142345, ..., 'IV', 'both', 'yes'],
#        [12258, 10006, 142345, ..., 'IV', 'both', 'yes']], dtype=object)

# %%
drug=set(g["drug"])

# %%
len(drug)
# Out:
# 19

# %%
a=[]
for i in drug:
    a.append(g[g["drug"]==i])

# %%
a[0]
# Out:
#    row_id_x  subject_id  hadm_id           admittime           dischtime  \
# 7     12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
#
#   deathtime admission_type    admission_location discharge_location insurance  \
# 7       NaN      EMERGENCY  EMERGENCY ROOM ADMIT   HOME HEALTH CARE  Medicare
#
#    ...     gsn          ndc  prod_strength dose_val_rx dose_unit_rx  \
# 7  ...  1408.0  165002241.0  140mg Cap PPK         140           mg
#
#   form_val_disp form_unit_disp  route  _merge  opioid_abuse
# 7             1            CAP     PO    both           yes
#
# [1 rows x 38 columns]

# %%
g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 39 to 27
# Data columns (total 38 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   row_id_x              30 non-null     int64
#  1   subject_id            30 non-null     int64
#  2   hadm_id               30 non-null     int64
#  3   admittime             30 non-null     datetime64[ns]
#  4   dischtime             30 non-null     datetime64[ns]
#  5   deathtime             0 non-null      object
#  6   admission_type        30 non-null     object
#  7   admission_location    30 non-null     object
#  8   discharge_location    30 non-null     object
#  9   insurance             30 non-null     object
#  10  language              0 non-null      object
#  11  religion              30 non-null     object
#  12  marital_status        30 non-null     object
#  13  ethnicity             30 non-null     object
# ...

# %%
cols=merged_df.columns

# %%
cols
# Out:
# Index(['row_id_x', 'subject_id', 'hadm_id', 'admittime', 'dischtime',
#        'deathtime', 'admission_type', 'admission_location',
#        'discharge_location', 'insurance', 'language', 'religion',
#        'marital_status', 'ethnicity', 'edregtime', 'edouttime', 'diagnosis',
#        'hospital_expire_flag', 'has_chartevents_data', 'row_id_y',
#        'icustay_id', 'startdate', 'enddate', 'drug_type', 'drug',
#        'drug_name_poe', 'drug_name_generic', 'formulary_drug_cd', 'gsn', 'ndc',
#        'prod_strength', 'dose_val_rx', 'dose_unit_rx', 'form_val_disp',
#        'form_unit_disp', 'route', '_merge'],
#       dtype='object')

# %%
merged_df["admdiff"]=(merged_df.dischtime-merged_df.admittime)

# %%
merged_df["admdiff"]=merged_df["admdiff"].apply(lambda x:x.days+1)

# %%
merged_df
# Out:
#        row_id_x  subject_id  hadm_id           admittime           dischtime  \
# 0         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 1         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 2         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 3         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 4         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# ...         ...         ...      ...                 ...                 ...
# 10400     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10401     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10402     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10403     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10404     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
#
# ...

# %%
merged_df["dosgdiff"]=merged_df["enddate"]-merged_df["startdate"]

# %%
merged_df["dosgdiff"]=merged_df["dosgdiff"].apply(lambda x:x.days+1 if x.days==0 else x.days)

# %%
merged_df
# Out:
#        row_id_x  subject_id  hadm_id           admittime           dischtime  \
# 0         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 1         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 2         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 3         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 4         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# ...         ...         ...      ...                 ...                 ...
# 10400     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10401     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10402     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10403     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10404     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
#
# ...

# %%
patdays=pd.DataFrame()

# %%
patdays
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in list(set(merged_df["subject_id"])):
    patdays[i]=[merged_df[merged_df["subject_id"]==i].admdiff.sum()]

# %%
patdays
# Out:
#    40456  42033  44083  40503  42066  42075  44154  40595  42135  40601  ...  \
# 0     87     40   1092     26    679   2254     40   1197   5331    539  ...
#
#    10127  10130  10132  43927  42412  41914  42430  42458  41976  41983
# 0   3266     20   3050    425    315   1462    304     30   8208    114
#
# [1 rows x 100 columns]

# %%
merged_df["maxdays"]=merged_df["subject_id"].apply(lambda x:patdays[x][0]+1)

# %%
merged_df
# Out:
#        row_id_x  subject_id  hadm_id           admittime           dischtime  \
# 0         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 1         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 2         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 3         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 4         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# ...         ...         ...      ...                 ...                 ...
# 10400     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10401     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10402     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10403     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10404     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
#
# ...

# %%
set(merged_df["form_unit_disp"])
# Out:
# {'AERO',
#  'AMP',
#  'Appl',
#  'BAG',
#  'BTL',
#  'CAN',
#  'CAP',
#  'DBTL',
#  'DEV',
#  'DRP',
#  'INH',
#  'KIT',
#  'LOZ',
#  'NEB',
#  'PKT',
#  'PTCH',
#  'SPRY',
#  'SUPP',
#  'SYR',
#  'TAB',
#  'TROC',
#  'TUBE',
#  'UDCUP',
#  'UNIT',
#  'VIAL',
#  'dose',
#  'g',
#  'gm',
#  'mL',
#  'mg',
#  'million units',
#  'ml',
#  nan}

# %%
import matplotlib.pyplot as plt

# %%
merged_df[merged_df["dosgdiff"]>merged_df["admdiff"]]
# Out:
#       row_id_x  subject_id  hadm_id           admittime           dischtime  \
# 2955     12362       10111   174739 2000-01-14 18:42:00 2000-02-01 17:17:00
# 4306     39821       40124   126179 2000-02-04 02:26:00 2000-02-10 17:39:00
# 5598     39929       40503   168803 2006-07-06 19:59:00 2006-07-07 19:00:00
# 7582     40422       42033   154156 2001-07-26 17:13:00 2001-07-28 16:02:00
# 7583     40422       42033   154156 2001-07-26 17:13:00 2001-07-28 16:02:00
# 7586     40422       42033   154156 2001-07-26 17:13:00 2001-07-28 16:02:00
# 7588     40422       42033   154156 2001-07-26 17:13:00 2001-07-28 16:02:00
# 7589     40422       42033   154156 2001-07-26 17:13:00 2001-07-28 16:02:00
#
#                 deathtime admission_type         admission_location  \
# 2955  2180-02-01 17:17:00      EMERGENCY       EMERGENCY ROOM ADMIT
# 4306                  NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 5598  2186-07-07 19:00:00      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# ...

# %%
merged_df=merged_df.drop(115,axis=0)

# %%
merged_df[merged_df["dosgdiff"]>merged_df["admdiff"]]
# Out:
#       row_id_x  subject_id  hadm_id           admittime           dischtime  \
# 2955     12362       10111   174739 2000-01-14 18:42:00 2000-02-01 17:17:00
# 4306     39821       40124   126179 2000-02-04 02:26:00 2000-02-10 17:39:00
# 5598     39929       40503   168803 2006-07-06 19:59:00 2006-07-07 19:00:00
# 7582     40422       42033   154156 2001-07-26 17:13:00 2001-07-28 16:02:00
# 7583     40422       42033   154156 2001-07-26 17:13:00 2001-07-28 16:02:00
# 7586     40422       42033   154156 2001-07-26 17:13:00 2001-07-28 16:02:00
# 7588     40422       42033   154156 2001-07-26 17:13:00 2001-07-28 16:02:00
# 7589     40422       42033   154156 2001-07-26 17:13:00 2001-07-28 16:02:00
#
#                 deathtime admission_type         admission_location  \
# 2955  2180-02-01 17:17:00      EMERGENCY       EMERGENCY ROOM ADMIT
# 4306                  NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 5598  2186-07-07 19:00:00      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# ...

# %%
condition1 = (merged_df["dosgdiff"] / merged_df["admdiff"]) > 0.5
condition2 = merged_df['drug'].str.contains('|'.join(opioids), case=False, na=False)
condition3 = merged_df["drug_type"]=='ADDITIVE'

# Combine conditions using bitwise OR
merged_df["opioid_abuse"] = (condition1 | condition2|condition3).map({True: "yes", False: "No"})

# %%
merged_df[merged_df["opioid_abuse"]=="No"]
# Out:
#        row_id_x  subject_id  hadm_id           admittime           dischtime  \
# 1         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 7         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 10        12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 11        12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 12        12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# ...         ...         ...      ...                 ...                 ...
# 10400     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10401     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10402     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10403     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10404     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
#
# ...

# %%
merged_df
# Out:
#        row_id_x  subject_id  hadm_id           admittime           dischtime  \
# 0         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 1         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 2         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 3         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 4         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# ...         ...         ...      ...                 ...                 ...
# 10400     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10401     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10402     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10403     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10404     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
#
# ...

# %%
merged_df.columns
# Out:
# Index(['row_id_x', 'subject_id', 'hadm_id', 'admittime', 'dischtime',
#        'deathtime', 'admission_type', 'admission_location',
#        'discharge_location', 'insurance', 'language', 'religion',
#        'marital_status', 'ethnicity', 'edregtime', 'edouttime', 'diagnosis',
#        'hospital_expire_flag', 'has_chartevents_data', 'row_id_y',
#        'icustay_id', 'startdate', 'enddate', 'drug_type', 'drug',
#        'drug_name_poe', 'drug_name_generic', 'formulary_drug_cd', 'gsn', 'ndc',
#        'prod_strength', 'dose_val_rx', 'dose_unit_rx', 'form_val_disp',
#        'form_unit_disp', 'route', '_merge', 'opioid_abuse', 'admdiff',
#        'dosgdiff', 'maxdays'],
#       dtype='object')

# %%
len(merged_df[merged_df["opioid_abuse"]=="yes"])
# Out:
# 2574

# %%
len(merged_df[merged_df["opioid_abuse"]=="No"])
# Out:
# 7830

# %%
merged_df
# Out:
#        row_id_x  subject_id  hadm_id           admittime           dischtime  \
# 0         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 1         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 2         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 3         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 4         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# ...         ...         ...      ...                 ...                 ...
# 10400     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10401     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10402     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10403     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10404     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
#
# ...

# %%
merged_df=merged_df.drop("deathtime",axis=1)

# %%
merged_df.columns
# Out:
# Index(['row_id_x', 'subject_id', 'hadm_id', 'admittime', 'dischtime',
#        'admission_type', 'admission_location', 'discharge_location',
#        'insurance', 'language', 'religion', 'marital_status', 'ethnicity',
#        'edregtime', 'edouttime', 'diagnosis', 'hospital_expire_flag',
#        'has_chartevents_data', 'row_id_y', 'icustay_id', 'startdate',
#        'enddate', 'drug_type', 'drug', 'drug_name_poe', 'drug_name_generic',
#        'formulary_drug_cd', 'gsn', 'ndc', 'prod_strength', 'dose_val_rx',
#        'dose_unit_rx', 'form_val_disp', 'form_unit_disp', 'route', '_merge',
#        'opioid_abuse', 'admdiff', 'dosgdiff', 'maxdays'],
#       dtype='object')

# %%
merged_df=merged_df.drop(["edregtime","edouttime","icustay_id",],axis=1)

# %%
merged_df.columns
# Out:
# Index(['row_id_x', 'subject_id', 'hadm_id', 'admittime', 'dischtime',
#        'admission_type', 'admission_location', 'discharge_location',
#        'insurance', 'language', 'religion', 'marital_status', 'ethnicity',
#        'diagnosis', 'hospital_expire_flag', 'has_chartevents_data', 'row_id_y',
#        'startdate', 'enddate', 'drug_type', 'drug', 'drug_name_poe',
#        'drug_name_generic', 'formulary_drug_cd', 'gsn', 'ndc', 'prod_strength',
#        'dose_val_rx', 'dose_unit_rx', 'form_val_disp', 'form_unit_disp',
#        'route', '_merge', 'opioid_abuse', 'admdiff', 'dosgdiff', 'maxdays'],
#       dtype='object')

# %%
set(merged_df.admission_type)
# Out:
# {'ELECTIVE', 'EMERGENCY', 'URGENT'}

# %%
merged_df["admission_type"]=merged_df["admission_type"].map({'ELECTIVE':3, 'EMERGENCY':1, 'URGENT':2})

# %%
merged_df=merged_df.drop("language",axis=1)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10404 entries, 0 to 10404
# Data columns (total 36 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   row_id_x              10404 non-null  int64
#  1   subject_id            10404 non-null  int64
#  2   hadm_id               10404 non-null  int64
#  3   admittime             10404 non-null  datetime64[ns]
#  4   dischtime             10404 non-null  datetime64[ns]
#  5   admission_type        10404 non-null  int64
#  6   admission_location    10404 non-null  object
#  7   discharge_location    10404 non-null  object
#  8   insurance             10404 non-null  object
#  9   religion              10403 non-null  object
#  10  marital_status        9544 non-null   object
#  11  ethnicity             10404 non-null  object
#  12  diagnosis             10404 non-null  object
#  13  hospital_expire_flag  10404 non-null  int64
# ...

# %%
set(merged_df.marital_status)
# Out:
# {'DIVORCED',
#  'MARRIED',
#  'SEPARATED',
#  'SINGLE',
#  'UNKNOWN (DEFAULT)',
#  'WIDOWED',
#  nan}

# %%
merged_df["marital_status"]=merged_df["marital_status"].fillna('UNKNOWN (DEFAULT)')

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10404 entries, 0 to 10404
# Data columns (total 36 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   row_id_x              10404 non-null  int64
#  1   subject_id            10404 non-null  int64
#  2   hadm_id               10404 non-null  int64
#  3   admittime             10404 non-null  datetime64[ns]
#  4   dischtime             10404 non-null  datetime64[ns]
#  5   admission_type        10404 non-null  int64
#  6   admission_location    10404 non-null  object
#  7   discharge_location    10404 non-null  object
#  8   insurance             10404 non-null  object
#  9   religion              10403 non-null  object
#  10  marital_status        10404 non-null  object
#  11  ethnicity             10404 non-null  object
#  12  diagnosis             10404 non-null  object
#  13  hospital_expire_flag  10404 non-null  int64
# ...

# %%
merged_df.columns
# Out:
# Index(['row_id_x', 'subject_id', 'hadm_id', 'admittime', 'dischtime',
#        'admission_type', 'admission_location', 'discharge_location',
#        'insurance', 'religion', 'marital_status', 'ethnicity', 'diagnosis',
#        'hospital_expire_flag', 'has_chartevents_data', 'row_id_y', 'startdate',
#        'enddate', 'drug_type', 'drug', 'drug_name_poe', 'drug_name_generic',
#        'formulary_drug_cd', 'gsn', 'ndc', 'prod_strength', 'dose_val_rx',
#        'dose_unit_rx', 'form_val_disp', 'form_unit_disp', 'route', '_merge',
#        'opioid_abuse', 'admdiff', 'dosgdiff', 'maxdays'],
#       dtype='object')

# %%
import numpy as np

# %%
list(set(merged_df["religion"]))[7]
# Out:
# 'PROTESTANT QUAKER'

# %%
merged_df[merged_df["religion"].isna()],1809
# Out:
# (      row_id_x  subject_id  hadm_id           admittime           dischtime  \
#  1809     12319       10069   146672 2008-02-08 11:15:00 2008-02-27 18:41:00
#
#        admission_type    admission_location discharge_location insurance  \
#  1809               1  EMERGENCY ROOM ADMIT       DEAD/EXPIRED  Medicaid
#
#       religion  ... dose_val_rx dose_unit_rx form_val_disp  form_unit_disp  \
#  1809      NaN  ...         NaN          NaN           NaN             NaN
#
#        route     _merge opioid_abuse admdiff dosgdiff maxdays
#  1809    NaN  left_only           No      20        1      21
#
#  [1 rows x 36 columns],
#  1809)

# %%
merged_df=merged_df.drop(index=1809,axis=0)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10403 entries, 0 to 10404
# Data columns (total 36 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   row_id_x              10403 non-null  int64
#  1   subject_id            10403 non-null  int64
#  2   hadm_id               10403 non-null  int64
#  3   admittime             10403 non-null  datetime64[ns]
#  4   dischtime             10403 non-null  datetime64[ns]
#  5   admission_type        10403 non-null  int64
#  6   admission_location    10403 non-null  object
#  7   discharge_location    10403 non-null  object
#  8   insurance             10403 non-null  object
#  9   religion              10403 non-null  object
#  10  marital_status        10403 non-null  object
#  11  ethnicity             10403 non-null  object
#  12  diagnosis             10403 non-null  object
#  13  hospital_expire_flag  10403 non-null  int64
# ...

# %%
merged_df=merged_df.drop(merged_df[merged_df.drug.isna()].index,axis=0)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10397 entries, 0 to 10404
# Data columns (total 36 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   row_id_x              10397 non-null  int64
#  1   subject_id            10397 non-null  int64
#  2   hadm_id               10397 non-null  int64
#  3   admittime             10397 non-null  datetime64[ns]
#  4   dischtime             10397 non-null  datetime64[ns]
#  5   admission_type        10397 non-null  int64
#  6   admission_location    10397 non-null  object
#  7   discharge_location    10397 non-null  object
#  8   insurance             10397 non-null  object
#  9   religion              10397 non-null  object
#  10  marital_status        10397 non-null  object
#  11  ethnicity             10397 non-null  object
#  12  diagnosis             10397 non-null  object
#  13  hospital_expire_flag  10397 non-null  int64
# ...

# %%
merged_df["ndc"]
# Out:
# 0        0.000000e+00
# 1        5.107908e+10
# 2        5.107908e+10
# 3        5.846800e+10
# 4        0.000000e+00
#              ...
# 10400    8.517410e+07
# 10401    6.332303e+10
# 10402    3.380703e+08
# 10403    4.097811e+08
# 10404    3.385002e+08
# Name: ndc, Length: 10397, dtype: float64

# %%
merged_df=merged_df.drop("ndc",axis=1)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10397 entries, 0 to 10404
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   row_id_x              10397 non-null  int64
#  1   subject_id            10397 non-null  int64
#  2   hadm_id               10397 non-null  int64
#  3   admittime             10397 non-null  datetime64[ns]
#  4   dischtime             10397 non-null  datetime64[ns]
#  5   admission_type        10397 non-null  int64
#  6   admission_location    10397 non-null  object
#  7   discharge_location    10397 non-null  object
#  8   insurance             10397 non-null  object
#  9   religion              10397 non-null  object
#  10  marital_status        10397 non-null  object
#  11  ethnicity             10397 non-null  object
#  12  diagnosis             10397 non-null  object
#  13  hospital_expire_flag  10397 non-null  int64
# ...

# %%
merged_df["drug_name_poe"]=merged_df["drug_name_poe"].fillna(merged_df["drug"])

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10397 entries, 0 to 10404
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   row_id_x              10397 non-null  int64
#  1   subject_id            10397 non-null  int64
#  2   hadm_id               10397 non-null  int64
#  3   admittime             10397 non-null  datetime64[ns]
#  4   dischtime             10397 non-null  datetime64[ns]
#  5   admission_type        10397 non-null  int64
#  6   admission_location    10397 non-null  object
#  7   discharge_location    10397 non-null  object
#  8   insurance             10397 non-null  object
#  9   religion              10397 non-null  object
#  10  marital_status        10397 non-null  object
#  11  ethnicity             10397 non-null  object
#  12  diagnosis             10397 non-null  object
#  13  hospital_expire_flag  10397 non-null  int64
# ...

# %%
merged_df["drug_name_generic"]=merged_df["drug_name_generic"].fillna(merged_df["drug"])

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10397 entries, 0 to 10404
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   row_id_x              10397 non-null  int64
#  1   subject_id            10397 non-null  int64
#  2   hadm_id               10397 non-null  int64
#  3   admittime             10397 non-null  datetime64[ns]
#  4   dischtime             10397 non-null  datetime64[ns]
#  5   admission_type        10397 non-null  int64
#  6   admission_location    10397 non-null  object
#  7   discharge_location    10397 non-null  object
#  8   insurance             10397 non-null  object
#  9   religion              10397 non-null  object
#  10  marital_status        10397 non-null  object
#  11  ethnicity             10397 non-null  object
#  12  diagnosis             10397 non-null  object
#  13  hospital_expire_flag  10397 non-null  int64
# ...

# %%
merged_df=merged_df.drop("gsn",axis=1)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10397 entries, 0 to 10404
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   row_id_x              10397 non-null  int64
#  1   subject_id            10397 non-null  int64
#  2   hadm_id               10397 non-null  int64
#  3   admittime             10397 non-null  datetime64[ns]
#  4   dischtime             10397 non-null  datetime64[ns]
#  5   admission_type        10397 non-null  int64
#  6   admission_location    10397 non-null  object
#  7   discharge_location    10397 non-null  object
#  8   insurance             10397 non-null  object
#  9   religion              10397 non-null  object
#  10  marital_status        10397 non-null  object
#  11  ethnicity             10397 non-null  object
#  12  diagnosis             10397 non-null  object
#  13  hospital_expire_flag  10397 non-null  int64
# ...

# %%
merged_df[merged_df.columns[6:13]]=merged_df[merged_df.columns[6:13]].astype('string')

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10397 entries, 0 to 10404
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   row_id_x              10397 non-null  int64
#  1   subject_id            10397 non-null  int64
#  2   hadm_id               10397 non-null  int64
#  3   admittime             10397 non-null  datetime64[ns]
#  4   dischtime             10397 non-null  datetime64[ns]
#  5   admission_type        10397 non-null  int64
#  6   admission_location    10397 non-null  string
#  7   discharge_location    10397 non-null  string
#  8   insurance             10397 non-null  string
#  9   religion              10397 non-null  string
#  10  marital_status        10397 non-null  string
#  11  ethnicity             10397 non-null  string
#  12  diagnosis             10397 non-null  string
#  13  hospital_expire_flag  10397 non-null  int64
# ...

# %%
merged_df[merged_df.columns[18:29]]=merged_df[merged_df.columns[18:29]].astype('string')

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10397 entries, 0 to 10404
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   row_id_x              10397 non-null  int64
#  1   subject_id            10397 non-null  int64
#  2   hadm_id               10397 non-null  int64
#  3   admittime             10397 non-null  datetime64[ns]
#  4   dischtime             10397 non-null  datetime64[ns]
#  5   admission_type        10397 non-null  int64
#  6   admission_location    10397 non-null  string
#  7   discharge_location    10397 non-null  string
#  8   insurance             10397 non-null  string
#  9   religion              10397 non-null  string
#  10  marital_status        10397 non-null  string
#  11  ethnicity             10397 non-null  string
#  12  diagnosis             10397 non-null  string
#  13  hospital_expire_flag  10397 non-null  int64
# ...

# %% [raw]
# merged_df["formulary_drug_cd"]

# %%
merged_df["formulary_drug_cd"]
# Out:
# 0        NACLFLUSH
# 1           GLIP10
# 2           METO50
# 3          SEVE800
# 4          INSULIN
#            ...
# 10400    CIPR400PM
# 10401       CALG1I
# 10402      KCL20PM
# 10403    METR500PM
# 10404       CEFX1F
# Name: formulary_drug_cd, Length: 10397, dtype: string

# %%
merged_df["prod_strength"]
# Out:
# 0                                           Syringe
# 1                                          10MG TAB
# 2                                          50mg Tab
# 3                                         800mg Tab
# 4        Dummy Pkg for POE pump and PHA SS ordering
#                             ...
# 10400                              400mg Premix Bag
# 10401                                  1g/10mL Vial
# 10402                             20mEq/50mL Premix
# 10403                              500mg Premix Bag
# 10404                                 1g Frozen Bag
# Name: prod_strength, Length: 10397, dtype: string

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10397 entries, 0 to 10404
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   row_id_x              10397 non-null  int64
#  1   subject_id            10397 non-null  int64
#  2   hadm_id               10397 non-null  int64
#  3   admittime             10397 non-null  datetime64[ns]
#  4   dischtime             10397 non-null  datetime64[ns]
#  5   admission_type        10397 non-null  int64
#  6   admission_location    10397 non-null  string
#  7   discharge_location    10397 non-null  string
#  8   insurance             10397 non-null  string
#  9   religion              10397 non-null  string
#  10  marital_status        10397 non-null  string
#  11  ethnicity             10397 non-null  string
#  12  diagnosis             10397 non-null  string
#  13  hospital_expire_flag  10397 non-null  int64
# ...

# %%
set(merged_df.admission_location)
# Out:
# {'CLINIC REFERRAL/PREMATURE',
#  'EMERGENCY ROOM ADMIT',
#  'PHYS REFERRAL/NORMAL DELI',
#  'TRANSFER FROM HOSP/EXTRAM',
#  'TRANSFER FROM SKILLED NUR'}

# %%
set(merged_df.ethnicity)
# Out:
# {'AMERICAN INDIAN/ALASKA NATIVE FEDERALLY RECOGNIZED TRIBE',
#  'ASIAN',
#  'BLACK/AFRICAN AMERICAN',
#  'HISPANIC OR LATINO',
#  'HISPANIC/LATINO - PUERTO RICAN',
#  'OTHER',
#  'UNABLE TO OBTAIN',
#  'UNKNOWN/NOT SPECIFIED',
#  'WHITE'}

# %%
import seaborn as sn

# %%
sn.countplot(data=merged_df, x='opioid_abuse', hue='admission_location', palette='muted')
plt.title('Opioid Abuse Cases by Language')
plt.xlabel('Language')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Opioid Abuse')

# %%
sn.countplot(data=merged_df, x='opioid_abuse', hue='opioid_abuse', palette='muted')
plt.title('Opioid Abuse Cases by Language')
plt.xlabel('Language')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Opioid Abuse')

# %%
sn.countplot(data=merged_df, x='opioid_abuse', hue='discharge_location', palette='muted')
plt.title('Opioid Abuse Cases by Language')
plt.xlabel('Language')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Opioid Abuse')

# %%
sn.countplot(data=merged_df, x='opioid_abuse', hue='religion', palette='muted')
plt.title('Opioid Abuse Cases by Language')
plt.xlabel('Language')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Opioid Abuse')

# %%
sn.countplot(data=merged_df, x='opioid_abuse', hue='marital_status', palette='muted')
plt.title('Opioid Abuse Cases by Language')
plt.xlabel('Language')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Opioid Abuse')

# %%
merged_df=merged_df.drop(["religion","ethnicity"],axis=1)

# %%
merged_df.iloc[:,0:20]
# Out:
#        row_id_x  subject_id  hadm_id           admittime           dischtime  \
# 0         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 1         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 2         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 3         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# 4         12258       10006   142345 2004-10-23 21:09:00 2004-11-01 17:15:00
# ...         ...         ...      ...                 ...                 ...
# 10400     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10401     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10402     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10403     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
# 10404     41092       44228   103379 2000-12-15 03:14:00 2000-12-24 18:00:00
#
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10397 entries, 0 to 10404
# Data columns (total 32 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   row_id_x              10397 non-null  int64
#  1   subject_id            10397 non-null  int64
#  2   hadm_id               10397 non-null  int64
#  3   admittime             10397 non-null  datetime64[ns]
#  4   dischtime             10397 non-null  datetime64[ns]
#  5   admission_type        10397 non-null  int64
#  6   admission_location    10397 non-null  string
#  7   discharge_location    10397 non-null  string
#  8   insurance             10397 non-null  string
#  9   marital_status        10397 non-null  string
#  10  diagnosis             10397 non-null  string
#  11  hospital_expire_flag  10397 non-null  int64
#  12  has_chartevents_data  10397 non-null  int64
#  13  row_id_y              10397 non-null  float64
# ...

# %%
cols=merged_df.columns

# %%
merged_df=merged_df.drop([cols[0],cols[2],cols[6],cols[7],cols[12],cols[13],cols[20],cols[21],cols[26],cols[27],cols[29],cols[30],cols[31]],axis=1)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10397 entries, 0 to 10404
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   subject_id            10397 non-null  int64
#  1   admittime             10397 non-null  datetime64[ns]
#  2   dischtime             10397 non-null  datetime64[ns]
#  3   admission_type        10397 non-null  int64
#  4   insurance             10397 non-null  string
#  5   marital_status        10397 non-null  string
#  6   diagnosis             10397 non-null  string
#  7   hospital_expire_flag  10397 non-null  int64
#  8   startdate             10397 non-null  datetime64[ns]
#  9   enddate               10397 non-null  datetime64[ns]
#  10  drug_type             10397 non-null  string
#  11  drug                  10397 non-null  string
#  12  drug_name_poe         10397 non-null  string
#  13  drug_name_generic     10397 non-null  string
# ...

# %%
merged_df.to_csv("patient.csv")

# %%
pdf=pd.read_csv("patient.csv")

# %%
pdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10397 entries, 0 to 10396
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            10397 non-null  int64
#  1   subject_id            10397 non-null  int64
#  2   admittime             10397 non-null  object
#  3   dischtime             10397 non-null  object
#  4   admission_type        10397 non-null  int64
#  5   insurance             10397 non-null  object
#  6   marital_status        10397 non-null  object
#  7   diagnosis             10397 non-null  object
#  8   hospital_expire_flag  10397 non-null  int64
#  9   startdate             10397 non-null  object
#  10  enddate               10397 non-null  object
#  11  drug_type             10397 non-null  object
#  12  drug                  10397 non-null  object
#  13  drug_name_poe         10397 non-null  object
#  14  drug_name_generic     10397 non-null  object
# ...

# %%
pdf=pdf.drop(index=68,axis=0)

# %%
pdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10396 entries, 0 to 10396
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            10396 non-null  int64
#  1   subject_id            10396 non-null  int64
#  2   admittime             10396 non-null  object
#  3   dischtime             10396 non-null  object
#  4   admission_type        10396 non-null  int64
#  5   insurance             10396 non-null  object
#  6   marital_status        10396 non-null  object
#  7   diagnosis             10396 non-null  object
#  8   hospital_expire_flag  10396 non-null  int64
#  9   startdate             10396 non-null  object
#  10  enddate               10396 non-null  object
#  11  drug_type             10396 non-null  object
#  12  drug                  10396 non-null  object
#  13  drug_name_poe         10396 non-null  object
#  14  drug_name_generic     10396 non-null  object
# ...

# %%
df=pdf.to_csv("patient.csv")

# %%
df=pd.read_csv("patient.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10396 entries, 0 to 10395
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0.1          10396 non-null  int64
#  1   Unnamed: 0            10396 non-null  int64
#  2   subject_id            10396 non-null  int64
#  3   admittime             10396 non-null  object
#  4   dischtime             10396 non-null  object
#  5   admission_type        10396 non-null  int64
#  6   insurance             10396 non-null  object
#  7   marital_status        10396 non-null  object
#  8   diagnosis             10396 non-null  object
#  9   hospital_expire_flag  10396 non-null  int64
#  10  startdate             10396 non-null  object
#  11  enddate               10396 non-null  object
#  12  drug_type             10396 non-null  object
#  13  drug                  10396 non-null  object
#  14  drug_name_poe         10396 non-null  object
# ...

# %%
df['startdate'] = pd.to_datetime(df['startdate'], errors='coerce')
df['enddate'] = pd.to_datetime(df['enddate'], errors='coerce')
df['admittime'] = pd.to_datetime(df['admittime'], errors='coerce')
df['dischtime'] = pd.to_datetime(df['dischtime'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10396 entries, 0 to 10395
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0.1          10396 non-null  int64
#  1   Unnamed: 0            10396 non-null  int64
#  2   subject_id            10396 non-null  int64
#  3   admittime             10396 non-null  datetime64[ns]
#  4   dischtime             10396 non-null  datetime64[ns]
#  5   admission_type        10396 non-null  int64
#  6   insurance             10396 non-null  object
#  7   marital_status        10396 non-null  object
#  8   diagnosis             10396 non-null  object
#  9   hospital_expire_flag  10396 non-null  int64
#  10  startdate             10396 non-null  datetime64[ns]
#  11  enddate               10396 non-null  datetime64[ns]
#  12  drug_type             10396 non-null  object
#  13  drug                  10396 non-null  object
# ...

# %%
df.to_csv("patient.csv")

# %%
df=pd.to_datetime(df["admittime"])

# %%
def csv(df):
    cols=df.columns
    df=df.drop(cols[:2],axis=1)
    columns = df.columns
    column_definitions = []
    # Define SQL column types based on data types in CSV
    for col in columns:
        dtype = str(df[col].dtype)
        if dtype == 'object':
            column_definitions.append(f"{col} VARCHAR(255)")
        elif dtype == 'int64':
            column_definitions.append(f"{col} INT")
        elif dtype == 'float64':
            column_definitions.append(f"{col} FLOAT")
        elif dtype == 'bool':
            column_definitions.append(f"{col} BOOLEAN")
        else:
            column_definitions.append(f"{col} TEXT")  # Fallback for other types

    column_definitions_str = ', '.join(column_definitions)
    create_table_sql = f"CREATE TABLE IF NOT EXISTS patient ({column_definitions_str})"
    
    return create_table_sql

# %%
csv(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 csv(df)
#
# Cell In[111], line 2, in csv(df)
#       1 def csv(df):
# ----> 2     cols=df.columns
#       3     df=df.drop(cols[:2],axis=1)
#       4     columns = df.columns
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
cols=df.columns
df=df.drop(cols[:2],axis=1)
columns = df.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 cols=df.columns
#       2 df=df.drop(cols[:2],axis=1)
#       3 columns = df.columns
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
df
# Out:
# 0       2004-10-23 21:09:00
# 1       2004-10-23 21:09:00
# 2       2004-10-23 21:09:00
# 3       2004-10-23 21:09:00
# 4       2004-10-23 21:09:00
#                 ...
# 10391   2000-12-15 03:14:00
# 10392   2000-12-15 03:14:00
# 10393   2000-12-15 03:14:00
# 10394   2000-12-15 03:14:00
# 10395   2000-12-15 03:14:00
# Name: admittime, Length: 10396, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 10396 entries, 0 to 10395
# Series name: admittime
# Non-Null Count  Dtype
# --------------  -----
# 10396 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 81.3 KB

# %%
cols
# Out:
# Index(['row_id_x', 'subject_id', 'hadm_id', 'admittime', 'dischtime',
#        'admission_type', 'admission_location', 'discharge_location',
#        'insurance', 'marital_status', 'diagnosis', 'hospital_expire_flag',
#        'has_chartevents_data', 'row_id_y', 'startdate', 'enddate', 'drug_type',
#        'drug', 'drug_name_poe', 'drug_name_generic', 'formulary_drug_cd',
#        'prod_strength', 'dose_val_rx', 'dose_unit_rx', 'form_val_disp',
#        'form_unit_disp', 'route', '_merge', 'opioid_abuse', 'admdiff',
#        'dosgdiff', 'maxdays'],
#       dtype='object')

# %%
columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 columns
#
# NameError: name 'columns' is not defined

# %%
csv(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 csv(df)
#
# Cell In[111], line 2, in csv(df)
#       1 def csv(df):
# ----> 2     cols=df.columns
#       3     df=df.drop(cols[:2],axis=1)
#       4     columns = df.columns
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'

# %% [markdown]
# ------embedding for categorical datas------

# %%
#tokenization

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
tokenize=Tokenizer(oov_token="<OOV>")

# %%
tokenize.fit_on_texts(merged_df["insurance"])

# %%
import pickle

# %%
with open('ins.pkl', 'wb') as file:
    pickle.dump(tokenize, file)

# %%
tokens=tokenize.texts_to_sequences(merged_df["drug"])

# %%
len(merged_df["hadm_id"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hadm_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
len(set((merged_df["hadm_id"])))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hadm_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10397 entries, 0 to 10404
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   subject_id            10397 non-null  int64
#  1   admittime             10397 non-null  datetime64[ns]
#  2   dischtime             10397 non-null  datetime64[ns]
#  3   admission_type        10397 non-null  int64
#  4   insurance             10397 non-null  string
#  5   marital_status        10397 non-null  string
#  6   diagnosis             10397 non-null  string
#  7   hospital_expire_flag  10397 non-null  int64
#  8   startdate             10397 non-null  datetime64[ns]
#  9   enddate               10397 non-null  datetime64[ns]
#  10  drug_type             10397 non-null  string
#  11  drug                  10397 non-null  string
#  12  drug_name_poe         10397 non-null  string
#  13  drug_name_generic     10397 non-null  string
# ...

# %%
set(merged_df["route"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'route'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
set(merged_df["drug_type"])
# Out:
# {'ADDITIVE', 'BASE', 'MAIN'}

# %%
len(merged_df[merged_df.opioid_abuse=="yes"])
# Out:
# 2573

# %%
merged_df["drug"][0:9]
# Out:
# 0    Sodium Chloride 0.9%  Flush
# 1                      Glipizide
# 2                     Metoprolol
# 3                      Sevelamer
# 4                        Insulin
# 5                   Pantoprazole
# 6                  Acetaminophen
# 7                Magnesium Oxide
# 8                Docusate Sodium
# Name: drug, dtype: string

# %%
tokens
# Out:
# [[2, 1, 3, 4, 17],
#  [197],
#  [19],
#  [243],
#  [12],
#  [28],
#  [23],
#  [21, 207],
#  [30, 2],
#  [40],
#  [21, 7],
#  [221],
#  [5, 1],
#  [221],
#  [93, 16],
#  [132, 26],
#  [61, 16],
#  [61, 16],
#  [66],
#  [71],
#  [95],
#  [91, 23],
#  [208, 209, 210],
#  [49],
#  [431, 16],
#  [243],
#  [243],
#  [208, 209, 210],
#  [52],
#  [109],
#  [153],
#  [5, 1],
#  [132, 26],
#  [66],
#  [96, 97, 98],
#  [71],
#  [99],
#  [66],
#  [22, 16],
#  [234, 2],
#  [349],
#  [22, 16],
#  [22, 16],
#  [21, 7],
#  [22, 16],
#  [13, 14, 6],
#  [9],
#  [8],
#  [9],
#  [9],
#  [13, 14, 6],
#  [13, 14, 6],
#  [8],
#  [8],
#  [10],
#  [129],
#  [129],
#  [23],
#  [147, 350],
#  [52],
#  [208, 209, 210],
#  [21, 7],
#  [41, 43, 27],
#  [208, 209, 210],
#  [18, 7],
#  [41, 43, 27],
#  [15, 2],
#  [99],
#  [297],
#  [138],
#  [278],
#  [28, 2],
#  [100, 16],
#  [138],
#  [198],
#  [18, 7],
#  [198],
#  [18, 7],
#  [8],
#  [13, 14, 6],
#  [8],
#  [8],
#  [8],
#  [9],
#  [8],
#  [8],
#  [8],
#  [8],
# ...

# %%
word_index=tokenize.word_index

# %%
word_index
# Out:
# {'chloride': 1,
#  'sodium': 2,
#  '0': 3,
#  '9': 4,
#  'potassium': 5,
#  'dextrose': 6,
#  'sulfate': 7,
#  'd5w': 8,
#  'ns': 9,
#  'furosemide': 10,
#  '5': 11,
#  'insulin': 12,
#  'iso': 13,
#  'osmotic': 14,
#  'heparin': 15,
#  'hcl': 16,
#  'flush': 17,
#  'morphine': 18,
#  'metoprolol': 19,
#  'sw': 20,
#  'magnesium': 21,
#  'vancomycin': 22,
#  'acetaminophen': 23,
#  'calcium': 24,
#  'gluconate': 25,
#  'tartrate': 26,
#  'neb': 27,
#  'pantoprazole': 28,
#  'soln': 29,
#  'docusate': 30,
#  'albuterol': 31,
#  'fentanyl': 32,
#  'bag': 33,
#  '1': 34,
#  'lorazepam': 35,
#  'bisacodyl': 36,
#  'ml': 37,
#  'lr': 38,
#  'citrate': 39,
#  'senna': 40,
#  'ipratropium': 41,
#  'oral': 42,
#  'bromide': 43,
#  'bicarbonate': 44,
#  '2': 45,
#  '083': 46,
#  'hydromorphone': 47,
#  '12': 48,
#  'warfarin': 49,
#  'prednisone': 50,
#  'na': 51,
#  'aspirin': 52,
#  'vial': 53,
#  'mini': 54,
#  'plus': 55,
#  'phosphate': 56,
#  'd5': 57,
#  'units': 58,
# ...

# %%
max_length = max(len(seq) for seq in tokens)
drug_name_padded = pad_sequences(tokens, maxlen=max_length)

# %%
len(drug_name_padded)

# %%
print(drug_name_padded[0:1000])

# %%
# create embedding layer

# %%
from tensorflow.keras.layers import Embedding

# %%
out_dim=3
in_dim=len(word_index)+1

# %%
embedding_layer=Embedding(input_dim=in_dim,output_dim=out_dim)

# %%
#add embedding with LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense

# %%
model=Sequential()
model.add(embedding_layer)
model.add(LSTM(32))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
from sklearn

# %%
drug_name_padded

# %%
#shuffle it

# %%
index=np.arange(0,len(drug_name_padded))

# %%
index[0]

# %%
np.random.shuffle(index)

# %%
padded_drug=[drug_name_padded[i] for i in index]

# %%
padded_drug

# %%
train=padded_drug[0:10000]
test=padded_drug[10000:]

# %%
train=np.array(train)
test=np.array(test)

# %%
len(train)

# %%
history = model.fit(train,np.zeros(len(train)), epochs=10, batch_size=20, validation_split=0.2)

# %%
embedding_layer=model.layers[0]

# %%
embedding_weights=embedding_layer.get_weights()[0]

# %%
word_index = tokenize.word_index
drug_vectors = {}

for word, index in word_index.items():
    vector = embedding_weights[index]
    drug_vectors[word] = vector

print(drug_vectors)

# %%
from tensorflow.keras.layers import GlobalAveragePooling1D
# Get the embeddings for the padded sequences
embedding_model = Sequential()
embedding_model.add(embedding_layer)
embedding_model.add(GlobalAveragePooling1D())


# Convert padded_sequences to embeddings
embeddings = embedding_model.predict(train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[122], line 3
#       1 from tensorflow.keras.layers import GlobalAveragePooling1D
#       2 # Get the embeddings for the padded sequences
# ----> 3 embedding_model = Sequential()
#       4 embedding_model.add(embedding_layer)
#       5 embedding_model.add(GlobalAveragePooling1D())
#
# NameError: name 'Sequential' is not defined

# %%
embeddings

# %%
len(embeddings)

# %%
# important intakes drug_vectors, embedding_model,pipeline

# %%
class Vectorize:
    def __init__(self,col):
        col=[i.strip() for i in col]
        self.col=col
        
    def tokenize(self):
        self.tokenize.fit_on_texts(self.col)
        self.tokens=self.tokenize.texts_to_sequences(self.col)
        return self.tokenize.word_index,self.tokenize,self.tokens
    
    def padding(self):
        maxlength=max([len(i) for i in self.tokens])
        self.padded=pad_sequences(self.tokens,maxlength)
        return self.padded
    
    def embedding(self):
        in_dim=len(self.tokenize.word_index)+1
        out_dim=3
        embedding_layer=Embedding(input_dim=in_dim,output_dim=out_dim)
        self.model=Sequential()
        self.model.add(embedding_layer)
        self.model.add(LSTM(32))
        self.model.add(Dense(1, activation='sigmoid'))
        self.model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
        return self.model
    
    def train(self):
        history=self.model.fit(self.padded,
                          np.zeros(len(self.padded)),
                          epochs=10,
                          batch_size=32,
                          validation_split=0.2)
        return self.model
    
    def get_vectors(self):
        self.embedding_layer=self.model.layers[0]
        self.embedding_weights=self.embedding_layer.get_weights()[0]
        word_index = self.tokenize.word_index
        self.word_vectors = {}
        for word, index in word_index.items():
            vector = self.embedding_weights[index]
            self.word_vectors[word] = vector
            
        return self.word_vectors
    
    def padded_embedding(self):
        self.embedding_model = Sequential()
        self.embedding_model.add(self.embedding_layer)
        self.embedding_model.add(GlobalAveragePooling1D())
        
        return self.embedding_model

# %%
merged_df

# %%
merged_df=merged_df.sort_values(by="admittime")

# %%
merged_df.info()

# %%
cols=merged_df.columns

# %%
new_cols_names={}

# %%
a=3
def fun():
    global a
    a=2
fun()

# %%
print(a)

# %%
from tensorflow.keras.layers import

# %%
def columns_vectorize(merged_df,cols):

    col=Vectorize(merged_df[cols])
    col_word_index,col_tokenize,col_tokens=col.tokenize()
    col_padded=col.padding()
    col.embedding()
    col_model=col.train()
    col_word_vectors=col.get_vectors()
    col_model=col.padded_embedding()
    col_vectorized=col_model.predict(col_padded)

    V1=[];V2=[];V3=[]
    for i in col_vectorized:
        V1.append(i[0])
        V2.append(i[1])
        V3.append(i[2])
    merged_df[sv1]=V1
    merged_df[sv2]=V2
    merged_df[sv3]=V3
    
    return col_word_index,col_tokenize,col_tokens

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10397 entries, 0 to 10404
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   subject_id            10397 non-null  int64
#  1   admittime             10397 non-null  datetime64[ns]
#  2   dischtime             10397 non-null  datetime64[ns]
#  3   admission_type        10397 non-null  int64
#  4   insurance             10397 non-null  string
#  5   marital_status        10397 non-null  string
#  6   diagnosis             10397 non-null  string
#  7   hospital_expire_flag  10397 non-null  int64
#  8   startdate             10397 non-null  datetime64[ns]
#  9   enddate               10397 non-null  datetime64[ns]
#  10  drug_type             10397 non-null  string
#  11  drug                  10397 non-null  string
#  12  drug_name_poe         10397 non-null  string
#  13  drug_name_generic     10397 non-null  string
# ...

# %%
from tensorflow.keras.layers import Embedding,LSTM,Dense
from tensorflow.keras.models import Sequential

# %%
insmodel=columns_vectorize(merged_df,"insurance")
# Out:
# Epoch 1/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9846 - loss: 0.4626 - val_accuracy: 1.0000 - val_loss: 0.0084
# Epoch 2/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 3/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 6.1573e-04
# Epoch 4/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 9.6176e-04 - val_accuracy: 1.0000 - val_loss: 3.3627e-04
# Epoch 5/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 5.4472e-04 - val_accuracy: 1.0000 - val_loss: 2.1186e-04
# Epoch 6/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 3.3820e-04 - val_accuracy: 1.0000 - val_loss: 1.4522e-04
# Epoch 7/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 2.4304e-04 - val_accuracy: 1.0000 - val_loss: 1.0520e-04
# Epoch 8/10
# ...

# %%
with open("insmodel.pkl","wb") as file:
    pickle.dump(insmodel,file)

# %%
mrgmodel=columns_vectorize(merged_df,"marital_status")
# Out:
# Epoch 1/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9831 - loss: 0.3746 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 2/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 3.1184e-04
# Epoch 3/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 1.0000 - loss: 3.3056e-04 - val_accuracy: 1.0000 - val_loss: 1.5182e-04
# Epoch 4/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 1.0000 - loss: 1.6950e-04 - val_accuracy: 1.0000 - val_loss: 9.2548e-05
# Epoch 5/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 1.0416e-04 - val_accuracy: 1.0000 - val_loss: 6.3123e-05
# Epoch 6/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 7.1955e-05 - val_accuracy: 1.0000 - val_loss: 4.6202e-05
# Epoch 7/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 5.2262e-05 - val_accuracy: 1.0000 - val_loss: 3.5383e-05
# Epoch 8/10
# ...

# %%
with open("mrgmodel.pkl","wb") as file:
    pickle.dump(mrgmodel,file)

# %%
diagmodel=columns_vectorize(merged_df,"diagnosis")
# Out:
# Epoch 1/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9722 - loss: 0.2060 - val_accuracy: 1.0000 - val_loss: 3.0643e-04
# Epoch 2/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 2.5132e-04 - val_accuracy: 1.0000 - val_loss: 1.4161e-04
# Epoch 3/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 1.2335e-04 - val_accuracy: 1.0000 - val_loss: 8.1895e-05
# Epoch 4/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 1.0000 - loss: 7.4720e-05 - val_accuracy: 1.0000 - val_loss: 5.6171e-05
# Epoch 5/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 5.2234e-05 - val_accuracy: 1.0000 - val_loss: 4.1289e-05
# Epoch 6/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 1.0000 - loss: 3.8764e-05 - val_accuracy: 1.0000 - val_loss: 3.1635e-05
# Epoch 7/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 1.0000 - loss: 2.9922e-05 - val_accuracy: 1.0000 - val_loss: 2.4932e-05
# Epoch 8/10
# ...

# %%
with open("diagmodel.pkl","wb") as file:
    pickle.dump(diagmodel,file)

# %%
drgtmodel=columns_vectorize(merged_df,"drug_type")
# Out:
# Epoch 1/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9772 - loss: 0.4567 - val_accuracy: 1.0000 - val_loss: 0.0088
# Epoch 2/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 3/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 7.7970e-04
# Epoch 4/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 8.7529e-04 - val_accuracy: 1.0000 - val_loss: 4.3000e-04
# Epoch 5/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 5.1840e-04 - val_accuracy: 1.0000 - val_loss: 2.7161e-04
# Epoch 6/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 1.0000 - loss: 2.9727e-04 - val_accuracy: 1.0000 - val_loss: 1.8570e-04
# Epoch 7/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 2.0086e-04 - val_accuracy: 1.0000 - val_loss: 1.3398e-04
# Epoch 8/10
# ...

# %%
with open("drgtmodel.pkl","wb") as file:
    pickle.dump(drgtmodel,file)

# %%
drgmodel=columns_vectorize(merged_df,"drug")
# Out:
# Epoch 1/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9971 - loss: 0.1886 - val_accuracy: 1.0000 - val_loss: 4.1016e-04
# Epoch 2/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 3.0899e-04 - val_accuracy: 1.0000 - val_loss: 1.8233e-04
# Epoch 3/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.5479e-04 - val_accuracy: 1.0000 - val_loss: 1.1014e-04
# Epoch 4/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 1.0000 - loss: 9.7989e-05 - val_accuracy: 1.0000 - val_loss: 7.5283e-05
# Epoch 5/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 6.8974e-05 - val_accuracy: 1.0000 - val_loss: 5.4988e-05
# Epoch 6/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 1.0000 - loss: 5.0913e-05 - val_accuracy: 1.0000 - val_loss: 4.1793e-05
# Epoch 7/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 1.0000 - loss: 3.8805e-05 - val_accuracy: 1.0000 - val_loss: 3.2723e-05
# Epoch 8/10
# ...

# %%
with open("drgmodel.pkl","wb") as file:
    pickle.dump(drgmodel,file)

# %%
drgnpmodel=columns_vectorize(merged_df,"drug_name_poe")
# Out:
# Epoch 1/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.9875 - loss: 0.2230 - val_accuracy: 1.0000 - val_loss: 7.4773e-04
# Epoch 2/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 5.6741e-04 - val_accuracy: 1.0000 - val_loss: 3.1469e-04
# Epoch 3/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 1.0000 - loss: 2.6910e-04 - val_accuracy: 1.0000 - val_loss: 1.7975e-04
# Epoch 4/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.5858e-04 - val_accuracy: 1.0000 - val_loss: 1.1767e-04
# Epoch 5/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 1.0000 - loss: 1.0682e-04 - val_accuracy: 1.0000 - val_loss: 8.3249e-05
# Epoch 6/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 7.6603e-05 - val_accuracy: 1.0000 - val_loss: 6.1873e-05
# Epoch 7/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 5.7777e-05 - val_accuracy: 1.0000 - val_loss: 4.7572e-05
# Epoch 8/10
# ...

# %%
with open("drgnpmodel.pkl","wb") as file:
    pickle.dump(drgnpmodel,file)

# %%
drgngmodel=columns_vectorize(merged_df,"drug_name_generic")
# Out:
# Epoch 1/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.9926 - loss: 0.1937 - val_accuracy: 1.0000 - val_loss: 4.2792e-04
# Epoch 2/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 1.0000 - loss: 3.1093e-04 - val_accuracy: 1.0000 - val_loss: 1.7163e-04
# Epoch 3/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 1.0000 - loss: 1.4510e-04 - val_accuracy: 1.0000 - val_loss: 1.0175e-04
# Epoch 4/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 1.0000 - loss: 9.0564e-05 - val_accuracy: 1.0000 - val_loss: 6.9371e-05
# Epoch 5/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 1.0000 - loss: 6.2804e-05 - val_accuracy: 1.0000 - val_loss: 5.0794e-05
# Epoch 6/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 4.6845e-05 - val_accuracy: 1.0000 - val_loss: 3.8878e-05
# Epoch 7/10
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 1.0000 - loss: 3.6115e-05 - val_accuracy: 1.0000 - val_loss: 3.0650e-05
# Epoch 8/10
# ...

# %%
with open("drgngmodel.pkl","wb") as file:
    pickle.dump(drgngmodel,file)

# %%
columns_vectorize(merged_df,cols,6,"admlV1","admlV2","admlV3")

# %%
merged_df.info()

# %%
columns_vectorize(merged_df,merged_df.columns,7,"dischlV1","dischlV2","dischlV3")

# %%
merged_df.info()

# %%
from tensorflow.keras.layers import GlobalAveragePooling1D

# %%
def column_vectorize(merged_df,cols,pos,sv1,sv2,sv3):
    col=Vectorize(merged_df[cols[pos]])
    col_word_index,col_tokenize,col_tokens=col.tokenize()
    maxlength=max([len(i) for i in col_tokens])
    return col_word_index,col_tokenize,maxlength

# %%
ins=column_vectorize(merged_df,cols,8,"insV")
mrg=column_vectorize(merged_df,cols,9,"mrgsV")
diag=column_vectorize(merged_df,cols,10,"diagV")

# %%
print(mrg)

# %%
import pickle
with open('ins.pkl', 'wb') as f:
    pickle.dump(ins, f)

# %%
with open('mrg.pkl', 'wb') as f:
    pickle.dump(mrg, f)

# %%
with open('diag.pkl', 'wb') as f:
    pickle.dump(diag, f)

# %%
merged_df.info()

# %%
merged_df["opioid_abuse"]=merged_df["opioid_abuse"].apply(lambda x:1 if x=="yes" else 0)

# %%
merged_df.info()

# %%
set(merged_df["dose_unit_rx"])

# %%
drgtype=column_vectorize(merged_df,cols,16,"drgtV")
drg=column_vectorize(merged_df,cols,17,"drgV")
drgnamepoe=column_vectorize(merged_df,cols,18,"drgnpV")
drgnamegeneric=column_vectorize(merged_df,cols,19,"drgngV)

# %%
with open('drgtype.pkl', 'wb') as f:
    pickle.dump(drgtype, f)

# %%
with open('drg.pkl', 'wb') as f:
    pickle.dump(drg, f)

# %%
with open('drgnamepoe.pkl', 'wb') as f:
    pickle.dump(drgnamepoe, f)

# %%
with open('drgnamegeneric.pkl', 'wb') as f:
    pickle.dump(drgnamegeneric, f)

# %%
new_cols_names

# %%
merged_df.info()

# %%
columns_vectorize(merged_df,cols,26,"routeV1","routeV2","routeV3")

# %%
merged_df.info()

# %%
l=[]
def drug():
    for i in merged_df["dose_val_rx"]:
        if "-" in i:
            s1=i.split("-")
            if s1[0][-1].isalpha() or s1[1][-1].isalpha():
                l.append(1)
            else:
                s1=[float(j) for j in s1]
                r=[j for j in range(int(s1[0]),int(s1[1])+1)]
                l.append(sum(r)/(int(s1[1])-int(s1[1])+1))
        else :
            if "," in i:
                s=""
                for j in i:
                    if j!=",":
                        s+=j
                l.append(float(s))
            else:
                l.append(float(i))

    print(len(l))

# %%
merged_df["dose_val_rx"]=l

# %%
l=[]
for i in merged_df["form_val_disp"]:
    if "-" in i:
        s1=i.split("-")
        if s1[0][-1].isalpha() or s1[1][-1].isalpha():
            l.append(1)
        else:
            s1=[float(j) for j in s1]
            r=[j for j in range(int(s1[0]),int(s1[1])+1)]
            l.append(sum(r)/(int(s1[1])-int(s1[1])+1))
    else :
        if "," in i:
            s=""
            for j in i:
                if j!=",":
                    s+=j
            l.append(float(s))
        else:
            l.append(float(i))
    
print(len(l))

# %%
merged_df["form_val_disp"]=l

# %%
merged_df.info()

# %%
set(merged_df["dose_unit_rx"])

# %%
medication_and_dosage = {
    'mcg': 1,
    'mcg/h': 2,
    'mcg/hr': 3,
    'mg': 4,
    'mg PE': 5,
    'g': 6,
    'gm': 7,
    'mEq': 8,
    'ml': 9,
    'mL': 10,
    'mmol': 11,
    'million units': 12,
    'dose': 13,
    'UNIT': 14,
    'UDCUP': 15,
    'gtt': 16,
    'DROP': 17,
    'BAG': 18,
    'PKT': 19,
    'CAP': 20,
    'TAB': 21,
    'LOZ': 22,
    'TROC': 23,
    'SPRY': 24,
    'SYR': 25,
    'PUFF': 26,
    'INH': 27,
    'NEB': 28,
    'Enema': 29,
    'AMP': 30,
    'VIAL': 31,
    'PTCH': 32,
    'Appl': 33,
    'L': 34,
    'in': 35
}

# %%
merged_df["dose_unit_rx"]=merged_df["dose_unit_rx"].apply(lambda x:medication_and_dosage[x])

# %%
merged_df.info()

# %%
set(merged_df["form_unit_disp"])

# %%
medication_and_dosage1 = {
    '<NA>': 1,
    'g': 2,
    'gm': 3,
    'mg': 4,
    'mL': 5,
    'ml': 6,
    'million units': 7,
    'dose': 8,
    'UNIT': 9,
    'UDCUP': 10,
    'gtt': 11,
    'DRP': 12,
    'DROP': 13,
    'BAG': 14,
    'PKT': 15,
    'CAP': 16,
    'TAB': 17,
    'LOZ': 18,
    'TROC': 19,
    'SPRY': 20,
    'SYR': 21,
    'PUFF': 22,
    'INH': 23,
    'NEB': 24,
    'Enema': 25,
    'AMP': 26,
    'VIAL': 27,
    'PTCH': 28,
    'Appl': 29,
    'TUBE': 30,
    'AERO': 31,
    'CAN': 32,
    'KIT': 33,
    'DEV': 34,
    'BTL': 35,
    'DBTL': 36,
    'SUPP': 37
}

# %%
merged_df["form_unit_disp"]=merged_df["form_unit_disp"].apply(lambda x:medication_and_dosage1[x] if x in medication_and_dosage1 else 1)

# %%
set(merged_df["form_unit_disp"])

# %%
merged_df.info()

# %%
merged_df=merged_df.drop([cols[6],cols[7],cols[8],cols[9],cols[10],cols[16],cols[17],cols[18],cols[19],cols[26],cols[27]],axis=1)

# %%
merged_df.info()

# %%
cols=merged_df.columns

# %%
merged_df=merged_df.drop([cols[11],cols[12]],axis=1)

# %%
merged_df.info()

# %%
len(merged_df)

# %%
merged_df.shape[0]

# %%
merged_df.to_csv("finaldata.csv",index=False)

# %%
df=pd.read_csv("finaldata.csv")

# %%
df

# %%
df.info()

# %%
df['startdate'] = pd.to_datetime(df['startdate'], errors='coerce')
df['enddate'] = pd.to_datetime(df['enddate'], errors='coerce')
df['admittime'] = pd.to_datetime(df['admittime'], errors='coerce')
df['dischtime'] = pd.to_datetime(df['dischtime'], errors='coerce')

# %%
df.info()

# %%
cols=df.columns

# %%
cols

# %%
df[cols[3]+'year'] = df[cols[3]].dt.year
df[cols[3]+'month'] = df[cols[3]].dt.month
df[cols[3]+'day'] = df[cols[3]].dt.day
df[cols[3]+'day_of_week'] = df[cols[3]].dt.dayofweek
df[cols[3]+'hour'] = df[cols[3]].dt.hour

# %%
df[cols[4]+'year'] = df[cols[4]].dt.year
df[cols[4]+'month'] = df[cols[4]].dt.month
df[cols[4]+'day'] = df[cols[4]].dt.day
df[cols[4]+'day_of_week'] = df[cols[4]].dt.dayofweek
df[cols[4]+'hour'] = df[cols[4]].dt.hour

# %%
df[cols[9]+'year'] = df[cols[9]].dt.year
df[cols[9]+'month'] = df[cols[9]].dt.month
df[cols[9]+'day'] = df[cols[9]].dt.day
df[cols[9]+'day_of_week'] = df[cols[9]].dt.dayofweek
df[cols[9]+'hour'] = df[cols[9]].dt.hour

# %%
df[cols[10]+'year'] = df[cols[10]].dt.year
df[cols[10]+'month'] = df[cols[10]].dt.month
df[cols[10]+'day'] = df[cols[10]].dt.day
df[cols[10]+'day_of_week'] = df[cols[10]].dt.dayofweek
df[cols[10]+'hour'] = df[cols[10]].dt.hour

# %%
df=df.drop([cols[3],cols[4],cols[9],cols[10]],axis=1)

# %%
df

# %%
cols

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, LeakyReLU, Input
from tensorflow.keras.models import Sequential, Model
import pandas as pd
import numpy as np

# Define Generator
def build_generator(input_dim=100, output_dim=48):
    model = Sequential([
        Dense(256, input_dim=input_dim),
        LeakyReLU(alpha=0.2),
        Dense(512),
        LeakyReLU(alpha=0.2),
        Dense(256),
        LeakyReLU(alpha=0.2),
        Dense(output_dim, activation='tanh')  # Output size should match your data features
    ])
    return model

# Define Discriminator
def build_discriminator(input_dim=48):
    model = Sequential([
        Dense(512, input_dim=input_dim),
        LeakyReLU(alpha=0.2),
        Dense(256),
        LeakyReLU(alpha=0.2),
        Dense(1, activation='sigmoid')  # Output is probability of being real
    ])
    return model

# Define GAN
def build_gan(generator, discriminator):
    discriminator.trainable = False  # Freeze the discriminator when training the GAN
    model = Sequential([generator, discriminator])
    return model

# Compile Models
def compile_models(generator, discriminator, gan):
    discriminator.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5))
    gan.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5))

# Normalize Data
def normalize_data(data):
    data_normalized = data.copy()
    min_max = {}
    for column in data.columns:
        if np.issubdtype(data[column].dtype, np.number):
            min_val = data[column].min()
            max_val = data[column].max()
            min_max[column] = (min_val, max_val)
            # Min-max normalization to [0, 1]
            data_normalized[column] = (data[column] - min_val) / (max_val - min_val)
            # Scale to [-1, 1]
            data_normalized[column] = (data_normalized[column] - 0.5) * 2
    return data_normalized, min_max

# Reverse Normalize Data
def reverse_normalize_data(data_normalized, min_max):
    data_reversed = data_normalized.copy()
    for column in data_normalized.columns:
        if column in min_max:
            min_val, max_val = min_max[column]
            data_reversed[column] = (data_normalized[column] / 2) + 0.5
            data_reversed[column] = data_reversed[column] * (max_val - min_val) + min_val
    return data_reversed

# Train GAN
def train_gan(generator, discriminator, gan, data, epochs=25, batch_size=64):
    for epoch in range(epochs):
        # Train Discriminator
        idx = np.random.randint(0, data.shape[0], batch_size)
        real_data = data.iloc[idx].values
        real_labels = np.ones((batch_size, 1))
        noise = np.random.normal(0, 1, (batch_size, input_dim))
        fake_data = generator.predict(noise)
        fake_labels = np.zeros((batch_size, 1))
        
        d_loss_real = discriminator.train_on_batch(real_data, real_labels)
        d_loss_fake = discriminator.train_on_batch(fake_data, fake_labels)
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
        
        # Train Generator
        noise = np.random.normal(0, 1, (batch_size, input_dim))
        g_loss = gan.train_on_batch(noise, np.ones((batch_size, 1)))
        
        if epoch % 1000 == 0:
            print(f'Epoch {epoch} | D Loss: {d_loss} | G Loss: {g_loss}')
# Step 1: Filter original data for 'opioid_abuse' == 'yes'
opioid_abuse_yes = df[df['opioid_abuse'] == 1]
opioid_abuse_yes=opioid_abuse_yes.drop([cols[0],cols[1],cols[2]],axis=1)

# Step 2: Normalize the filtered data
opioid_abuse_yes_normalized, min_max = normalize_data(opioid_abuse_yes)

# Step 3: Define the GAN components
input_dim = 100
output_dim = opioid_abuse_yes_normalized.shape[1]

generator = build_generator(input_dim, output_dim)
discriminator = build_discriminator(output_dim)
gan = build_gan(generator, discriminator)
compile_models(generator, discriminator, gan)

# Step 4: Train the GAN
train_gan(generator, discriminator, gan, opioid_abuse_yes_normalized)

# Step 5: Generate synthetic data
num_samples_to_generate = 4000
noise = np.random.normal(0, 1, (num_samples_to_generate, input_dim))
generated_data_normalized = generator.predict(noise)
generated_data_normalized_df = pd.DataFrame(generated_data_normalized, columns=opioid_abuse_yes.columns)

# Step 6: Reverse normalization on the generated data
generated_data = reverse_normalize_data(generated_data_normalized_df, min_max)

print(generated_data)

# %%
df.info()

# %%
generated_data["form_val_disp"].describe()

# %%
df[df["opioid_abuse"]==1]["form_val_disp"].describe()

# %%
a.split("-")[0]

# %%
a=[1,2]

# %%
sum(a)

# %%
merged_df[cols[24]]

# %%
col6_word_vectors

# %%
col6_word_vectors

# %%
padded_vectors

# %%
set(merged_df["admission_location"])

# %%
merged_df["Admloc1"]=

# %%
col6_vectors

# %%
col=merged_df["drug"]

# %% [markdown]
# ###### v=Vectorize(col)

# %%
v.tokenize()

# %%
v.padding()

# %%
cols
# Out:
# Index(['row_id_x', 'subject_id', 'hadm_id', 'admittime', 'dischtime',
#        'deathtime', 'admission_type', 'admission_location',
#        'discharge_location', 'insurance', 'language', 'religion',
#        'marital_status', 'ethnicity', 'edregtime', 'edouttime', 'diagnosis',
#        'hospital_expire_flag', 'has_chartevents_data', 'row_id_y',
#        'icustay_id', 'startdate', 'enddate', 'drug_type', 'drug',
#        'drug_name_poe', 'drug_name_generic', 'formulary_drug_cd', 'gsn', 'ndc',
#        'prod_strength', 'dose_val_rx', 'dose_unit_rx', 'form_val_disp',
#        'form_unit_disp', 'route', '_merge'],
#       dtype='object')

# %%
df=pd.read_csv("processesdata.csv")

# %%
columns=df.columns

# %%
columns
# Out:
# Index(['Unnamed: 0', 'subject_id', 'admission_type', 'hospital_expire_flag',
#        'dose_val_rx', 'dose_unit_rx', 'form_val_disp', 'form_unit_disp',
#        'opioid_abuse', 'admdiff', 'dosgdiff', 'maxdays', 'insV1', 'insV2',
#        'insV3', 'mrgsV1', 'mrgsV2', 'mrgsV3', 'diagV1', 'diagV2', 'diagV3',
#        'drgtV1', 'drgtV2', 'drgtV3', 'drgV1', 'drgV2', 'drgV3', 'drgnpV1',
#        'drgnpV2', 'drgnpV3', 'drgngV1', 'drgngV2', 'drgngV3', 'admittimeyear',
#        'dischtimeyear', 'startdateyear', 'enddateyear'],
#       dtype='object')

# %%
df=df.drop("maxdays",axis=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'subject_id', 'admission_type', 'hospital_expire_flag',
#        'dose_val_rx', 'dose_unit_rx', 'form_val_disp', 'form_unit_disp',
#        'opioid_abuse', 'admdiff', 'dosgdiff', 'insV1', 'insV2', 'insV3',
#        'mrgsV1', 'mrgsV2', 'mrgsV3', 'diagV1', 'diagV2', 'diagV3', 'drgtV1',
#        'drgtV2', 'drgtV3', 'drgV1', 'drgV2', 'drgV3', 'drgnpV1', 'drgnpV2',
#        'drgnpV3', 'drgngV1', 'drgngV2', 'drgngV3', 'admittimeyear',
#        'dischtimeyear', 'startdateyear', 'enddateyear'],
#       dtype='object')

# %%
df=df.drop("opioid_abuse",axis=1)

# %%
columns=df.columns

# %%
columns=columns[1:]

# %%
len(columns)
# Out:
# 34

# %%
columns
# Out:
# Index(['subject_id', 'admission_type', 'hospital_expire_flag', 'dose_val_rx',
#        'dose_unit_rx', 'form_val_disp', 'form_unit_disp', 'admdiff',
#        'dosgdiff', 'insV1', 'insV2', 'insV3', 'mrgsV1', 'mrgsV2', 'mrgsV3',
#        'diagV1', 'diagV2', 'diagV3', 'drgtV1', 'drgtV2', 'drgtV3', 'drgV1',
#        'drgV2', 'drgV3', 'drgnpV1', 'drgnpV2', 'drgnpV3', 'drgngV1', 'drgngV2',
#        'drgngV3', 'admittimeyear', 'dischtimeyear', 'startdateyear',
#        'enddateyear'],
#       dtype='object')

# %%
columns=columns[1:]

# %%
columns
# Out:
# Index(['admission_type', 'hospital_expire_flag', 'dose_val_rx', 'dose_unit_rx',
#        'form_val_disp', 'form_unit_disp', 'admdiff', 'dosgdiff', 'insV1',
#        'insV2', 'insV3', 'mrgsV1', 'mrgsV2', 'mrgsV3', 'diagV1', 'diagV2',
#        'diagV3', 'drgtV1', 'drgtV2', 'drgtV3', 'drgV1', 'drgV2', 'drgV3',
#        'drgnpV1', 'drgnpV2', 'drgnpV3', 'drgngV1', 'drgngV2', 'drgngV3',
#        'admittimeyear', 'dischtimeyear', 'startdateyear', 'enddateyear'],
#       dtype='object')

# %%
columns=list(columns)

# %%
cols=list(cols)

# %%
columns[8]
# Out:
# 'insV1'

# %%
columns[8]=cols[9]+"v1"

# %%
columns[9]=cols[9]+"v2"

# %%
columns[10]=cols[9]+"v3"

# %%
columns
# Out:
# ['admission_type',
#  'hospital_expire_flag',
#  'dose_val_rx',
#  'dose_unit_rx',
#  'form_val_disp',
#  'form_unit_disp',
#  'admdiff',
#  'dosgdiff',
#  'insurancev1',
#  'insurancev2',
#  'insurancev3',
#  'mrgsV1',
#  'mrgsV2',
#  'mrgsV3',
#  'diagV1',
#  'diagV2',
#  'diagV3',
#  'drgtV1',
#  'drgtV2',
#  'drgtV3',
#  'drgV1',
#  'drgV2',
#  'drgV3',
#  'drgnpV1',
#  'drgnpV2',
#  'drgnpV3',
#  'drgngV1',
#  'drgngV2',
#  'drgngV3',
#  'admittimeyear',
#  'dischtimeyear',
#  'startdateyear',
#  'enddateyear']

# %%
cols
# Out:
# ['row_id_x',
#  'subject_id',
#  'hadm_id',
#  'admittime',
#  'dischtime',
#  'deathtime',
#  'admission_type',
#  'admission_location',
#  'discharge_location',
#  'insurance',
#  'language',
#  'religion',
#  'marital_status',
#  'ethnicity',
#  'edregtime',
#  'edouttime',
#  'diagnosis',
#  'hospital_expire_flag',
#  'has_chartevents_data',
#  'row_id_y',
#  'icustay_id',
#  'startdate',
#  'enddate',
#  'drug_type',
#  'drug',
#  'drug_name_poe',
#  'drug_name_generic',
#  'formulary_drug_cd',
#  'gsn',
#  'ndc',
#  'prod_strength',
#  'dose_val_rx',
#  'dose_unit_rx',
#  'form_val_disp',
#  'form_unit_disp',
#  'route',
#  '_merge']

# %%
columns[11]=cols[12]+"v1"
columns[12]=cols[12]+"v2"
columns[13]=cols[12]+"v3"

# %%
columns
# Out:
# ['admission_type',
#  'hospital_expire_flag',
#  'dose_val_rx',
#  'dose_unit_rx',
#  'form_val_disp',
#  'form_unit_disp',
#  'admdiff',
#  'dosgdiff',
#  'insurancev1',
#  'insurancev2',
#  'insurancev3',
#  'marital_statusv1',
#  'marital_statusv2',
#  'marital_statusv3',
#  'diagV1',
#  'diagV2',
#  'diagV3',
#  'drgtV1',
#  'drgtV2',
#  'drgtV3',
#  'drgV1',
#  'drgV2',
#  'drgV3',
#  'drgnpV1',
#  'drgnpV2',
#  'drgnpV3',
#  'drgngV1',
#  'drgngV2',
#  'drgngV3',
#  'admittimeyear',
#  'dischtimeyear',
#  'startdateyear',
#  'enddateyear']

# %%
cols
# Out:
# ['row_id_x',
#  'subject_id',
#  'hadm_id',
#  'admittime',
#  'dischtime',
#  'deathtime',
#  'admission_type',
#  'admission_location',
#  'discharge_location',
#  'insurance',
#  'language',
#  'religion',
#  'marital_status',
#  'ethnicity',
#  'edregtime',
#  'edouttime',
#  'diagnosis',
#  'hospital_expire_flag',
#  'has_chartevents_data',
#  'row_id_y',
#  'icustay_id',
#  'startdate',
#  'enddate',
#  'drug_type',
#  'drug',
#  'drug_name_poe',
#  'drug_name_generic',
#  'formulary_drug_cd',
#  'gsn',
#  'ndc',
#  'prod_strength',
#  'dose_val_rx',
#  'dose_unit_rx',
#  'form_val_disp',
#  'form_unit_disp',
#  'route',
#  '_merge']

# %%
columns[14]=cols[16]+"v1"
columns[15]=cols[16]+"v2"
columns[16]=cols[16]+"v3"

# %%
columns
# Out:
# ['admission_type',
#  'hospital_expire_flag',
#  'dose_val_rx',
#  'dose_unit_rx',
#  'form_val_disp',
#  'form_unit_disp',
#  'admdiff',
#  'dosgdiff',
#  'insurancev1',
#  'insurancev2',
#  'insurancev3',
#  'marital_statusv1',
#  'marital_statusv2',
#  'marital_statusv3',
#  'diagnosisv1',
#  'diagnosisv2',
#  'diagnosisv3',
#  'drgtV1',
#  'drgtV2',
#  'drgtV3',
#  'drgV1',
#  'drgV2',
#  'drgV3',
#  'drgnpV1',
#  'drgnpV2',
#  'drgnpV3',
#  'drgngV1',
#  'drgngV2',
#  'drgngV3',
#  'admittimeyear',
#  'dischtimeyear',
#  'startdateyear',
#  'enddateyear']

# %%
cols
# Out:
# ['row_id_x',
#  'subject_id',
#  'hadm_id',
#  'admittime',
#  'dischtime',
#  'deathtime',
#  'admission_type',
#  'admission_location',
#  'discharge_location',
#  'insurance',
#  'language',
#  'religion',
#  'marital_status',
#  'ethnicity',
#  'edregtime',
#  'edouttime',
#  'diagnosis',
#  'hospital_expire_flag',
#  'has_chartevents_data',
#  'row_id_y',
#  'icustay_id',
#  'startdate',
#  'enddate',
#  'drug_type',
#  'drug',
#  'drug_name_poe',
#  'drug_name_generic',
#  'formulary_drug_cd',
#  'gsn',
#  'ndc',
#  'prod_strength',
#  'dose_val_rx',
#  'dose_unit_rx',
#  'form_val_disp',
#  'form_unit_disp',
#  'route',
#  '_merge']

# %%
columns[17]=cols[23]+"v1"
columns[18]=cols[23]+"v2"
columns[19]=cols[23]+"v3"

# %%
columns
# Out:
# ['admission_type',
#  'hospital_expire_flag',
#  'dose_val_rx',
#  'dose_unit_rx',
#  'form_val_disp',
#  'form_unit_disp',
#  'admdiff',
#  'dosgdiff',
#  'insurancev1',
#  'insurancev2',
#  'insurancev3',
#  'marital_statusv1',
#  'marital_statusv2',
#  'marital_statusv3',
#  'diagnosisv1',
#  'diagnosisv2',
#  'diagnosisv3',
#  'drug_typev1',
#  'drug_typev2',
#  'drug_typev3',
#  'drgV1',
#  'drgV2',
#  'drgV3',
#  'drgnpV1',
#  'drgnpV2',
#  'drgnpV3',
#  'drgngV1',
#  'drgngV2',
#  'drgngV3',
#  'admittimeyear',
#  'dischtimeyear',
#  'startdateyear',
#  'enddateyear']

# %%
cols
# Out:
# ['row_id_x',
#  'subject_id',
#  'hadm_id',
#  'admittime',
#  'dischtime',
#  'deathtime',
#  'admission_type',
#  'admission_location',
#  'discharge_location',
#  'insurance',
#  'language',
#  'religion',
#  'marital_status',
#  'ethnicity',
#  'edregtime',
#  'edouttime',
#  'diagnosis',
#  'hospital_expire_flag',
#  'has_chartevents_data',
#  'row_id_y',
#  'icustay_id',
#  'startdate',
#  'enddate',
#  'drug_type',
#  'drug',
#  'drug_name_poe',
#  'drug_name_generic',
#  'formulary_drug_cd',
#  'gsn',
#  'ndc',
#  'prod_strength',
#  'dose_val_rx',
#  'dose_unit_rx',
#  'form_val_disp',
#  'form_unit_disp',
#  'route',
#  '_merge']

# %%
columns[20]=cols[24]+"v1"
columns[21]=cols[24]+"v2"
columns[22]=cols[24]+"v3"

# %%
columns
# Out:
# ['admission_type',
#  'hospital_expire_flag',
#  'dose_val_rx',
#  'dose_unit_rx',
#  'form_val_disp',
#  'form_unit_disp',
#  'admdiff',
#  'dosgdiff',
#  'insurancev1',
#  'insurancev2',
#  'insurancev3',
#  'marital_statusv1',
#  'marital_statusv2',
#  'marital_statusv3',
#  'diagnosisv1',
#  'diagnosisv2',
#  'diagnosisv3',
#  'drug_typev1',
#  'drug_typev2',
#  'drug_typev3',
#  'drugv1',
#  'drugv2',
#  'drugv3',
#  'drgnpV1',
#  'drgnpV2',
#  'drgnpV3',
#  'drgngV1',
#  'drgngV2',
#  'drgngV3',
#  'admittimeyear',
#  'dischtimeyear',
#  'startdateyear',
#  'enddateyear']

# %%
columns[23]=cols[25]+"v1"
columns[24]=cols[25]+"v2"
columns[25]=cols[25]+"v3"

# %%
columns
# Out:
# ['admission_type',
#  'hospital_expire_flag',
#  'dose_val_rx',
#  'dose_unit_rx',
#  'form_val_disp',
#  'form_unit_disp',
#  'admdiff',
#  'dosgdiff',
#  'insurancev1',
#  'insurancev2',
#  'insurancev3',
#  'marital_statusv1',
#  'marital_statusv2',
#  'marital_statusv3',
#  'diagnosisv1',
#  'diagnosisv2',
#  'diagnosisv3',
#  'drug_typev1',
#  'drug_typev2',
#  'drug_typev3',
#  'drugv1',
#  'drugv2',
#  'drugv3',
#  'drug_name_poev1',
#  'drug_name_poev2',
#  'drug_name_poev3',
#  'drgngV1',
#  'drgngV2',
#  'drgngV3',
#  'admittimeyear',
#  'dischtimeyear',
#  'startdateyear',
#  'enddateyear']

# %%
columns[26]=cols[26]+"v1"
columns[27]=cols[26]+"v2"
columns[28]=cols[26]+"v3"

# %%
columns
# Out:
# ['admission_type',
#  'hospital_expire_flag',
#  'dose_val_rx',
#  'dose_unit_rx',
#  'form_val_disp',
#  'form_unit_disp',
#  'admdiff',
#  'dosgdiff',
#  'insurancev1',
#  'insurancev2',
#  'insurancev3',
#  'marital_statusv1',
#  'marital_statusv2',
#  'marital_statusv3',
#  'diagnosisv1',
#  'diagnosisv2',
#  'diagnosisv3',
#  'drug_typev1',
#  'drug_typev2',
#  'drug_typev3',
#  'drugv1',
#  'drugv2',
#  'drugv3',
#  'drug_name_poev1',
#  'drug_name_poev2',
#  'drug_name_poev3',
#  'drug_name_genericv1',
#  'drug_name_genericv2',
#  'drug_name_genericv3',
#  'admittimeyear',
#  'dischtimeyear',
#  'startdateyear',
#  'enddateyear']
