# %%
import pickle

# %%
with open('lstmmodel.pkl', 'rb') as file:
    loaded_model = pickle.load(file)

# %%
loaded_model
# Out:
# <Sequential name=sequential_12, built=True>

# %%
import pandas as pd

# %%
df=pd.read_csv("processesdata.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14345 entries, 0 to 14344
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            14345 non-null  int64
#  1   subject_id            14345 non-null  int64
#  2   admission_type        14345 non-null  float64
#  3   hospital_expire_flag  14345 non-null  float64
#  4   dose_val_rx           14345 non-null  float64
#  5   dose_unit_rx          14345 non-null  float64
#  6   form_val_disp         14345 non-null  float64
#  7   form_unit_disp        14345 non-null  float64
#  8   opioid_abuse          14345 non-null  float64
#  9   admdiff               14345 non-null  float64
#  10  dosgdiff              14345 non-null  float64
#  11  maxdays               14345 non-null  float64
#  12  insV1                 14345 non-null  float64
#  13  insV2                 14345 non-null  float64
# ...

# %%
df
# Out:
#        Unnamed: 0  subject_id  admission_type  hospital_expire_flag  \
# 0               0       10006        1.000000              0.000000
# 1               1       10006        1.000000              0.000000
# 2               2       10006        1.000000              0.000000
# 3               3       10006        1.000000              0.000000
# 4               4       10006        1.000000              0.000000
# ...           ...         ...             ...                   ...
# 14340       14340       44228        2.770105              0.141276
# 14341       14341       44228        2.856957              0.045161
# 14342       14342       44228        2.878041              0.073683
# 14343       14343       44228        2.835004              0.055065
# 14344       14344       44228        2.688204              0.101592
#
#        dose_val_rx  dose_unit_rx  form_val_disp  form_unit_disp  opioid_abuse  \
# ...

# %%
df[:][1:5]
# Out:
#    Unnamed: 0  subject_id  admission_type  hospital_expire_flag  dose_val_rx  \
# 1           1       10006             1.0                   0.0       1000.0
# 2           2       10006             1.0                   0.0        500.0
# 3           3       10006             1.0                   0.0        500.0
# 4           4       10006             1.0                   0.0        250.0
#
#    dose_unit_rx  form_val_disp  form_unit_disp  opioid_abuse  admdiff  ...  \
# 1           4.0         1000.0             4.0           0.0      9.0  ...
# 2           4.0            1.0            14.0           0.0      9.0  ...
# 3           4.0            1.0            17.0           0.0      9.0  ...
# 4           4.0            1.0            17.0           0.0      9.0  ...
#
#     drgnpV1   drgnpV2   drgnpV3   drgngV1   drgngV2   drgngV3  admittimeyear  \
# 1 -0.623171 -0.647766  0.639789 -0.667092  0.504449 -0.615771         2004.0
# ...

# %%
l=[];s=0;e=30
for i in range(0,5):
    l.append(df[:][s:e])
    s+=1;e+=1
# Out:
# [    Unnamed: 0  subject_id  admission_type  hospital_expire_flag  dose_val_rx  \
# 0            0       10006             1.0                   0.0          1.0
# 1            1       10006             1.0                   0.0       1000.0
# 2            2       10006             1.0                   0.0        500.0
# 3            3       10006             1.0                   0.0        500.0
# 4            4       10006             1.0                   0.0        250.0
# 5            5       10006             1.0                   0.0          0.5
# 6            6       10006             1.0                   0.0         10.0
# 7            7       10006             1.0                   0.0         20.0
# 8            8       10006             1.0                   0.0          3.0
# 9            9       10006             1.0                   0.0          1.0
# 10          10       10006             1.0                   0.0       1000.0
# ...

# %%
l[0]
# Out:
#     Unnamed: 0  subject_id  admission_type  hospital_expire_flag  dose_val_rx  \
# 0            0       10006             1.0                   0.0          1.0
# 1            1       10006             1.0                   0.0       1000.0
# 2            2       10006             1.0                   0.0        500.0
# 3            3       10006             1.0                   0.0        500.0
# 4            4       10006             1.0                   0.0        250.0
# 5            5       10006             1.0                   0.0          0.5
# 6            6       10006             1.0                   0.0         10.0
# 7            7       10006             1.0                   0.0         20.0
# 8            8       10006             1.0                   0.0          3.0
# 9            9       10006             1.0                   0.0          1.0
# 10          10       10006             1.0                   0.0       1000.0
# ...
